# %% [markdown]
# <a href="https://colab.research.google.com/github/jiedali/colab_temp/blob/main/breakout_run10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import time
import numpy as np
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
import gym
import random
from collections import deque
import matplotlib.pyplot as plt
# choose a GPU card
# os.environ['CUDA_VISIBLE_DEVICES']="0"
# Set seed for tensorflow
# SEED=123
# tf.set_random_seed(SEED)
# GYM_SEED=678
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Nov 20 19:17:11 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
def preprocess(image):
    """ prepro 210x160x3 uint8 frame into 6400 (80x80) 2D float array """
    image = image[35:195] # crop
    image = image[::2,::2,0] # downsample by factor of 2
    image[image == 144] = 0 # erase background (background type 1)
    image[image == 109] = 0 # erase background (background type 2)
    image[image != 0] = 1 # everything else just set to 1
    return np.reshape(image.astype(np.float).ravel(), [80,80])

# %%
# set seed
SEED=1
tf.set_random_seed(SEED)
GYM_SEED=567
env = gym.make("Breakout-v0")
obs = env.reset()
env.seed(GYM_SEED)
# Out:
# [567, 2126561800]

# %%
# CNN for modeling the DQN
state_size=[80,80,1]
action_size=env.action_space.n
n_outputs=action_size
input_height=80
input_width=80
input_channels=1
# Initial learning rate for RMSprop
learning_rate=0.00025
rmsprop_decay= 0.99
rmsprop_constant = 1e-6
# # Use adam optimizer
# beta_1=0.9
# beta_2=0.999
# epsilon=1e-07
#
# Note that the action space is 4 with following meanings:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']
class DQN(object):
	def __init__(self, state_size, action_size, learning_rate, name='online_q_network'):
		self.state_size = state_size
		self.action_size = action_size
		self.learning_rate = learning_rate
		self.name = name

		with tf.variable_scope(name):
			with tf.name_scope("inputs"):
				# Jieda note: state is preprocessd 80*80*1 array
				self.inputs = tf.placeholder(tf.float32, [None, input_height, input_width, input_channels], name="inputs")

			with tf.name_scope("conv1"):
				self.conv1 = tf.layers.conv2d(
					inputs=self.inputs, filters=32, kernel_size=[8, 8], strides=4,
					kernel_initializer=tf.variance_scaling_initializer(),
					padding="VALID", use_bias=False, name='conv1')

				self.conv1_out = tf.nn.relu(self.conv1, name='conv1_out')

			with tf.name_scope("conv2"):
				self.conv2 = tf.layers.conv2d(
					inputs=self.conv1_out, filters=64,
					kernel_size=[4, 4], strides=2, padding="VALID",
					kernel_initializer=tf.variance_scaling_initializer(),
					use_bias=False, name='conv2')

				self.conv2_out = tf.nn.relu(self.conv2, name='conv2_out')

			with tf.name_scope("conv3"):
				self.conv3 = tf.layers.conv2d(
					inputs=self.conv2_out, filters=64,
					kernel_size=[3, 3], strides=1, padding="VALID",
					kernel_initializer=tf.variance_scaling_initializer(),
					name="conv3")

				self.conv3_out = tf.nn.relu(self.conv3, name='conv3_out')

			with tf.name_scope("flatten"):
				self.flatten = tf.contrib.layers.flatten(self.conv3_out)

			with tf.name_scope("fc1"):
				self.fc1 = tf.layers.dense(inputs=self.flatten,
				                           units=512, activation=tf.nn.relu,
				                           kernel_initializer=tf.variance_scaling_initializer(), name="fc1")

			with tf.name_scope("fc1"):
				self.fc2 = tf.layers.dense(inputs=self.flatten,
				                           units=512, activation=tf.nn.relu,
				                           kernel_initializer=tf.variance_scaling_initializer(), name="fc2")

			with tf.name_scope("outputs"):
				self.outputs = tf.layers.dense(inputs=self.fc2,
				                               units=action_size,
				                               kernel_initializer=tf.variance_scaling_initializer(),
				                               activation=None)
		# Output is the approximated Action Values Q(s,a), so we don't need any activation

	def get_outputs(self):
		return self.outputs

	def get_weights(self, scope_name):
		# give all the weights of that network
		trainable_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=scope_name)
		# create a dictionary to contain the values of the network weights
		trainable_vars_by_name = {var.name[len(scope_name):]: var
		                          for var in trainable_vars}
		return trainable_vars_by_name

# %%
tf.reset_default_graph()
X_state = tf.placeholder(tf.float32, shape=[None, input_height, input_width, input_channels])
# initialize the two Q network
online_q = DQN(state_size, action_size, learning_rate, 'online_q_network')
target_q = DQN(state_size, action_size, learning_rate, 'target_q_network')
# get the output and weights from online q network
online_q_values = online_q.get_outputs()
online_q_weights = online_q.get_weights(scope_name='online_q_network')
# # get the output and weights from target q network
target_q_values = target_q.get_outputs()
target_q_weights = target_q.get_weights(scope_name='target_q_network')
# define the operation to copy the online network weights to target_q_network weights
copy_ops = [target_var.assign(online_q_weights[var_name]) for var_name, target_var in target_q_weights.items()]
#
copy_online_to_target = tf.group(*copy_ops)

with tf.variable_scope("train"):
	# define training operation
	input_action = tf.placeholder(tf.int32, shape=[None])
	y = tf.placeholder(tf.float32, shape=[None, 1])
	# Get the Q values for the input_action
	q_value = tf.reduce_sum(online_q_values * tf.one_hot(input_action, action_size), axis=1, keepdims=True)
	# compute the error between lable y and q_value from online_q_network approximation
	# Note that lable y is computed using the target_q_network
	error = tf.abs(y - q_value)
	clipped_error = tf.clip_by_value(error, 0, 1)
	linear_error = 2 * (error - clipped_error)
	loss = tf.reduce_mean(tf.square(clipped_error) + linear_error)

	# global_step is used to keep track of number of training steps completed
	global_step = tf.Variable(0, trainable=False, name='global_step')
	optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate, decay=rmsprop_decay, momentum=0.0, epsilon=rmsprop_constant, name='RMSProp')
	# optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=0.9, beta2=0.999, epsilon=1e-08,
	#                                    use_locking=False, name='Adam')
	training_op = optimizer.minimize(loss, global_step=global_step)

init = tf.global_variables_initializer()
saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From <ipython-input-7-da558a11b751>:40: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-7-da558a11b751>:68: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# reduced replay buffer size (see if it can avoid the RAM crashing issue)
replay_memory_size = 400000

# replay_memory = deque([],maxlen=replay_memory_size)
class ReplayBuffer:
	def __init__(self, maxlen):
		self.maxlen = maxlen
		self.buf = np.empty(shape=maxlen, dtype=np.object)
		self.index = 0
		self.length = 0

	def append(self, data):
		self.buf[self.index] = data
		self.length = min(self.length + 1, self.maxlen)
		self.index = (self.index + 1) % self.maxlen

	def sample(self, batch_size):
		# sample without replacement
		indices = np.random.permutation(self.length)[:batch_size]
		return self.buf[indices]

# create an instance of ReplayBuffer
replay_buffer = ReplayBuffer(replay_memory_size)

def sample_replay_buffer(batch_size):
	cols = [[], [], [], [], []]  # state, action, reward, next_state, continue
	for memory in replay_buffer.sample(batch_size):
		for col, value in zip(cols, memory):
			col.append(value)
	cols = [np.array(col) for col in cols]
	return cols[0], cols[1], cols[2].reshape(-1, 1), cols[3], cols[4].reshape(-1, 1)

eps_min = 0.1
eps_max = 1.0
eps_decay_steps = 2000000
def epsilon_greedy(q_values, step):
    # Note: we gradually decrease epsilon, we explore more in the beginning, less towards later
    epsilon = max(eps_min, eps_max-(eps_max-eps_min)*step/eps_decay_steps)
    if np.random.rand()<epsilon:
        return np.random.randint(n_outputs)
    else:
        return np.argmax(q_values)

# %%
# checkpoint path
checkpoint_path="/content/gdrive/MyDrive/breakout_run10.ckpt"
# This is the number of training steps
n_steps = 4000000
# In the very beginning, first have 10000 samples in the replay buffer
training_start=10000
# Before each training step, we run 4 episodes and add those samples to replay buffer
training_interval=4
save_steps=1000
copy_steps = 1000 # reduced the copy_steps from 2500 to 1000, to enable more frequent updates of the network
discount_rate=0.99
skip_start=90
batch_size=50
iteration=0
done=True
# initialize the tracking statistics
total_max_q=-float('inf')
mean_reward=0
total_reward=0
game_length=0
game_counter=0

with tf.Session() as sess:
	if os.path.isfile(checkpoint_path + ".index"):
		saver.restore(sess, checkpoint_path)
	else:
		init.run()
		# to make sure they have the same values to begin with
		# otherwise, different seeds will result in different initialized network weights
		copy_online_to_target.run()
	# intialize replay buffer
	replay_buffer = ReplayBuffer(replay_memory_size)
	# initialize 2 lists to store the final training results
	final_each_episode_rwd = []
	final_mean_max_q = []
	# start training
	# Training loop :
	# (1) collect M data points, add to replay buffer (play 4 episodes of game, add those to replay buffer)
	# (2) copy online network parameter to target network
	# (3) sample a batch from replay buffer, do the online network update (batch size:50)
	while True:
		step = global_step.eval()
		# if global training steps have meet the maximum, we will stop training
		if step >= n_steps:
			break
		# One iteration is just one sample generation !!!
		iteration += 1
		if done:
			obs = env.reset()
			for skip in range(skip_start):  # skip the beginning of each game
				obs, reward, done, info = env.step(0)  # take action 0
			state = preprocess(obs)
		state = state.reshape(1, 80, 80, 1)
		state_to_rb = state.reshape(80, 80, 1)

		# online network evaluates what to do
		q_values = online_q_values.eval(feed_dict={online_q.inputs: state})
		# q_values returns array of 4 values corresponding to 4 actions
		# for each step in the game, we record the max of q_values
		action = epsilon_greedy(q_values, step)

		# online network plays
		obs, reward, done, info = env.step(action)
		next_state = preprocess(obs)
		next_state = next_state.reshape(1, 80, 80, 1)
		next_state_to_rb = next_state.reshape(80, 80, 1)

		# Add this sample to the replay buffer
		replay_buffer.append((state_to_rb, action, reward, next_state_to_rb, 1.0 - done))
		# pass "next_state" to "state"
		state = next_state
		state_to_rb = next_state_to_rb

		# compute statistics to track training progress
		# track the maximum episode reward obtained so far, and the average episode reward
		total_reward += reward
		total_max_q += q_values.max()
		game_length += 1
		if done:
			game_counter += 1
			mean_max_q = total_max_q / game_length
			new_episode_reward = total_reward
			# print statistics after each game
			print("Iteration %d\tTraining step %d/%d  Mean Max Q %f last_episode_reward %d Game counts %d" % (
			iteration, step, n_steps, mean_max_q, total_reward, game_counter))
			# append the results to the final output
			final_each_episode_rwd.append(new_episode_reward)
			final_mean_max_q.append(mean_max_q)
			# reset the counters
			total_max_q = 0.0
			game_length = 0
			total_reward = 0

		# if number of samples are less than training_start(10000), or it is not a multiple of 4, we do not train
		if iteration < training_start or iteration % training_interval != 0:
			continue

		#     if iteration % 100 == 0: # print stats every 100 training steps
		#       print("Iteration %d\tTraining step %d/%d  Mean Max Q %f episode total reward %d average episode reward
		#       %f Game counts %d" %(iteration, step, n_steps, mean_max_q, total_reward, game_counter))
		#       print("Iteration %d\tTraining step %d/%d  Mean Max Q %f avg_rwds_30_episode %f  Game counts %d" %(
		#       iteration, step, n_steps, mean_max_q, avg_30_episode_rwd, game_counter))
		# otherwise, if iteration is more than 10,000 and it is a multiple of 4, we will update the network
		# result=sample_replay_buffer(batch_size)
		X_state_val, X_action_val, rewards, X_next_state_val, continues = sample_replay_buffer(batch_size)
		#
		next_q_values = target_q_values.eval(
			feed_dict={target_q.inputs: X_next_state_val}
		)
		max_next_q_values = np.max(next_q_values, axis=1, keepdims=True)
		y_val = rewards + continues * discount_rate * max_next_q_values

		# train online q network
		_, loss_val = sess.run([training_op, loss],
		                       feed_dict={online_q.inputs: X_state_val, input_action: X_action_val, y: y_val})

		# copy online q network to target network
		if step % copy_steps == 0:
			copy_online_to_target.run()

		# save dqn regularly
		if step % save_steps == 0:
			saver.save(sess, checkpoint_path)

			# save output to text
			#       with open('breakout_run1_cont_avg_30_episode_reward.txt', 'w') as file:
			#           file.write('%s\n' % final_avg30_epi_rwd)
			with open('/content/gdrive/MyDrive/breakout_run10_mean_max_q.txt', 'w') as file:
				file.write('%s\n' % final_mean_max_q)
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration 232802	Training step 55701/4000000  Mean Max Q 0.676295 last_episode_reward 2 Game counts 926
# Iteration 232987	Training step 55747/4000000  Mean Max Q 0.559317 last_episode_reward 0 Game counts 927
# Iteration 233163	Training step 55791/4000000  Mean Max Q 0.560509 last_episode_reward 0 Game counts 928
# Iteration 233433	Training step 55859/4000000  Mean Max Q 0.670691 last_episode_reward 2 Game counts 929
# Iteration 233663	Training step 55916/4000000  Mean Max Q 0.610001 last_episode_reward 1 Game counts 930
# Iteration 233855	Training step 55964/4000000  Mean Max Q 0.570226 last_episode_reward 0 Game counts 931
# Iteration 234139	Training step 56035/4000000  Mean Max Q 0.724143 last_episode_reward 2 Game counts 932
# Iteration 234377	Training step 56095/4000000  Mean Max Q 0.684922 last_episode_reward 1 Game counts 933
# Iteration 234679	Training step 56170/4000000  Mean Max Q 0.727826 last_episode_reward 3 Game counts 934
# Iteration 234919	Training step 56230/4000000  Mean Max Q 0.691865 last_episode_reward 1 Game counts 935
# Iteration 235097	Training step 56275/4000000  Mean Max Q 0.570225 last_episode_reward 0 Game counts 936
# Iteration 250919	Training step 60230/4000000  Mean Max Q 0.717954 last_episode_reward 1 Game counts 998
# Iteration 251089	Training step 60273/4000000  Mean Max Q 0.627210 last_episode_reward 0 Game counts 999
# Iteration 251449	Training step 60363/4000000  Mean Max Q 0.729539 last_episode_reward 3 Game counts 1000
# Iteration 251760	Training step 60440/4000000  Mean Max Q 0.763337 last_episode_reward 2 Game counts 1001
# Iteration 251933	Training step 60484/4000000  Mean Max Q 0.610610 last_episode_reward 0 Game counts 1002
# Iteration 252232	Training step 60558/4000000  Mean Max Q 0.765121 last_episode_reward 3 Game counts 1003
# Iteration 252471	Training step 60618/4000000  Mean Max Q 0.763736 last_episode_reward 1 Game counts 1004
# Iteration 252708	Training step 60677/4000000  Mean Max Q 0.757785 last_episode_reward 1 Game counts 1005
# Iteration 252955	Training step 60739/4000000  Mean Max Q 0.731209 last_episode_reward 1 Game counts 1006
# Iteration 253157	Training step 60790/4000000  Mean Max Q 0.728520 last_episode_reward 1 Game counts 1007
# Iteration 253457	Training step 60865/4000000  Mean Max Q 0.744901 last_episode_reward 2 Game counts 1008
# Iteration 253646	Training step 60912/4000000  Mean Max Q 0.618566 last_episode_reward 0 Game counts 1009
# Iteration 253868	Training step 60967/4000000  Mean Max Q 0.720493 last_episode_reward 1 Game counts 1010
# Iteration 254036	Training step 61009/4000000  Mean Max Q 0.619456 last_episode_reward 0 Game counts 1011
# Iteration 254314	Training step 61079/4000000  Mean Max Q 0.791879 last_episode_reward 2 Game counts 1012
# Iteration 254513	Training step 61129/4000000  Mean Max Q 0.688839 last_episode_reward 1 Game counts 1013
# Iteration 254805	Training step 61202/4000000  Mean Max Q 0.706790 last_episode_reward 2 Game counts 1014
# Iteration 255107	Training step 61277/4000000  Mean Max Q 0.821953 last_episode_reward 2 Game counts 1015
# Iteration 255392	Training step 61348/4000000  Mean Max Q 0.634756 last_episode_reward 2 Game counts 1016
# Iteration 255654	Training step 61414/4000000  Mean Max Q 0.693415 last_episode_reward 2 Game counts 1017
# Iteration 256031	Training step 61508/4000000  Mean Max Q 0.775433 last_episode_reward 3 Game counts 1018
# Iteration 256250	Training step 61563/4000000  Mean Max Q 0.700965 last_episode_reward 1 Game counts 1019
# Iteration 256465	Training step 61617/4000000  Mean Max Q 0.692522 last_episode_reward 1 Game counts 1020
# Iteration 256695	Training step 61674/4000000  Mean Max Q 0.744687 last_episode_reward 1 Game counts 1021
# Iteration 256965	Training step 61742/4000000  Mean Max Q 0.754273 last_episode_reward 2 Game counts 1022
# Iteration 257269	Training step 61818/4000000  Mean Max Q 0.766054 last_episode_reward 2 Game counts 1023
# Iteration 257442	Training step 61861/4000000  Mean Max Q 0.607239 last_episode_reward 0 Game counts 1024
# Iteration 257643	Training step 61911/4000000  Mean Max Q 0.620482 last_episode_reward 0 Game counts 1025
# Iteration 258010	Training step 62003/4000000  Mean Max Q 0.761401 last_episode_reward 3 Game counts 1026
# Iteration 258237	Training step 62060/4000000  Mean Max Q 0.739043 last_episode_reward 1 Game counts 1027
# Iteration 266299	Training step 64075/4000000  Mean Max Q 0.690628 last_episode_reward 4 Game counts 1058
# Iteration 266539	Training step 64135/4000000  Mean Max Q 0.709811 last_episode_reward 1 Game counts 1059
# Iteration 266775	Training step 64194/4000000  Mean Max Q 0.767276 last_episode_reward 1 Game counts 1060
# Iteration 266946	Training step 64237/4000000  Mean Max Q 0.623269 last_episode_reward 0 Game counts 1061
# Iteration 267181	Training step 64296/4000000  Mean Max Q 0.698798 last_episode_reward 1 Game counts 1062
# Iteration 267400	Training step 64350/4000000  Mean Max Q 0.713993 last_episode_reward 1 Game counts 1063
# Iteration 267575	Training step 64394/4000000  Mean Max Q 0.631601 last_episode_reward 0 Game counts 1064
# Iteration 267897	Training step 64475/4000000  Mean Max Q 0.744337 last_episode_reward 3 Game counts 1065
# Iteration 268311	Training step 64578/4000000  Mean Max Q 0.755568 last_episode_reward 4 Game counts 1066
# Iteration 268624	Training step 64656/4000000  Mean Max Q 0.814991 last_episode_reward 2 Game counts 1067
# Iteration 268966	Training step 64742/4000000  Mean Max Q 0.821804 last_episode_reward 3 Game counts 1068
# Iteration 269237	Training step 64810/4000000  Mean Max Q 0.711463 last_episode_reward 2 Game counts 1069
# Iteration 269514	Training step 64879/4000000  Mean Max Q 0.685748 last_episode_reward 2 Game counts 1070
# Iteration 269699	Training step 64925/4000000  Mean Max Q 0.640926 last_episode_reward 0 Game counts 1071
# Iteration 269964	Training step 64991/4000000  Mean Max Q 0.748067 last_episode_reward 2 Game counts 1072
# Iteration 270209	Training step 65053/4000000  Mean Max Q 0.776214 last_episode_reward 2 Game counts 1073
# Iteration 270380	Training step 65095/4000000  Mean Max Q 0.640228 last_episode_reward 0 Game counts 1074
# Iteration 270789	Training step 65198/4000000  Mean Max Q 0.809011 last_episode_reward 4 Game counts 1075
# Iteration 271026	Training step 65257/4000000  Mean Max Q 0.790501 last_episode_reward 1 Game counts 1076
# Iteration 271198	Training step 65300/4000000  Mean Max Q 0.639634 last_episode_reward 0 Game counts 1077
# Iteration 271407	Training step 65352/4000000  Mean Max Q 0.746005 last_episode_reward 1 Game counts 1078
# Iteration 271684	Training step 65421/4000000  Mean Max Q 0.816130 last_episode_reward 2 Game counts 1079
# Iteration 271954	Training step 65489/4000000  Mean Max Q 0.714024 last_episode_reward 1 Game counts 1080
# Iteration 272134	Training step 65534/4000000  Mean Max Q 0.647636 last_episode_reward 0 Game counts 1081
# Iteration 272397	Training step 65600/4000000  Mean Max Q 0.738195 last_episode_reward 1 Game counts 1082
# Iteration 272908	Training step 65727/4000000  Mean Max Q 0.767042 last_episode_reward 9 Game counts 1083
# Iteration 273090	Training step 65773/4000000  Mean Max Q 0.632692 last_episode_reward 0 Game counts 1084
# Iteration 273269	Training step 65818/4000000  Mean Max Q 0.640784 last_episode_reward 0 Game counts 1085
# Iteration 273502	Training step 65876/4000000  Mean Max Q 0.787273 last_episode_reward 1 Game counts 1086
# Iteration 273838	Training step 65960/4000000  Mean Max Q 0.782476 last_episode_reward 3 Game counts 1087
# Iteration 1432744	Training step 355686/4000000  Mean Max Q 1.058099 last_episode_reward 2 Game counts 5780
# Iteration 1432906	Training step 355727/4000000  Mean Max Q 1.001854 last_episode_reward 0 Game counts 5781
# Iteration 1433173	Training step 355794/4000000  Mean Max Q 1.157915 last_episode_reward 2 Game counts 5782
# Iteration 1433472	Training step 355868/4000000  Mean Max Q 1.002154 last_episode_reward 2 Game counts 5783
# Iteration 1433709	Training step 355928/4000000  Mean Max Q 0.967178 last_episode_reward 1 Game counts 5784
# Iteration 1433936	Training step 355984/4000000  Mean Max Q 1.098859 last_episode_reward 1 Game counts 5785
# Iteration 1434185	Training step 356047/4000000  Mean Max Q 1.104876 last_episode_reward 1 Game counts 5786
# Iteration 1434347	Training step 356087/4000000  Mean Max Q 1.036203 last_episode_reward 0 Game counts 5787
# Iteration 1434654	Training step 356164/4000000  Mean Max Q 1.058872 last_episode_reward 2 Game counts 5788
# Iteration 1434920	Training step 356230/4000000  Mean Max Q 1.072721 last_episode_reward 2 Game counts 5789
# Iteration 1435163	Training step 356291/4000000  Mean Max Q 1.125827 last_episode_reward 1 Game counts 5790
# Iteration 1435397	Training step 356350/4000000  Mean Max Q 0.958968 last_episode_reward 1 Game counts 5791
# Iteration 1435671	Training step 356418/4000000  Mean Max Q 1.074024 last_episode_reward 2 Game counts 5792
# Iteration 1435843	Training step 356461/4000000  Mean Max Q 1.039861 last_episode_reward 0 Game counts 5793
# Iteration 1436013	Training step 356504/4000000  Mean Max Q 1.012962 last_episode_reward 0 Game counts 5794
# Iteration 1436284	Training step 356571/4000000  Mean Max Q 0.941080 last_episode_reward 2 Game counts 5795
# Iteration 1436492	Training step 356623/4000000  Mean Max Q 1.021413 last_episode_reward 1 Game counts 5796
# Iteration 1436696	Training step 356674/4000000  Mean Max Q 1.159181 last_episode_reward 1 Game counts 5797
# Iteration 1436962	Training step 356741/4000000  Mean Max Q 1.092175 last_episode_reward 2 Game counts 5798
# Iteration 1437230	Training step 356808/4000000  Mean Max Q 1.015841 last_episode_reward 2 Game counts 5799
# Iteration 1437546	Training step 356887/4000000  Mean Max Q 1.024131 last_episode_reward 3 Game counts 5800
# Iteration 1437722	Training step 356931/4000000  Mean Max Q 1.020654 last_episode_reward 0 Game counts 5801
# Iteration 1437896	Training step 356974/4000000  Mean Max Q 1.017520 last_episode_reward 0 Game counts 5802
# Iteration 1438120	Training step 357030/4000000  Mean Max Q 1.171731 last_episode_reward 1 Game counts 5803
# Iteration 1438322	Training step 357081/4000000  Mean Max Q 1.032134 last_episode_reward 1 Game counts 5804
# Iteration 1438594	Training step 357149/4000000  Mean Max Q 0.928231 last_episode_reward 2 Game counts 5805
# Iteration 1438804	Training step 357201/4000000  Mean Max Q 0.849707 last_episode_reward 1 Game counts 5806
# Iteration 1438968	Training step 357242/4000000  Mean Max Q 1.001748 last_episode_reward 0 Game counts 5807
# Iteration 1439203	Training step 357301/4000000  Mean Max Q 1.145592 last_episode_reward 1 Game counts 5808
# Iteration 1439371	Training step 357343/4000000  Mean Max Q 1.010840 last_episode_reward 0 Game counts 5809
# Iteration 1439542	Training step 357386/4000000  Mean Max Q 1.002530 last_episode_reward 0 Game counts 5810
# Iteration 1439771	Training step 357443/4000000  Mean Max Q 0.990358 last_episode_reward 1 Game counts 5811
# Iteration 1440143	Training step 357536/4000000  Mean Max Q 0.981435 last_episode_reward 4 Game counts 5812
# Iteration 1440593	Training step 357649/4000000  Mean Max Q 1.003231 last_episode_reward 5 Game counts 5813
# Iteration 1440796	Training step 357699/4000000  Mean Max Q 1.046702 last_episode_reward 1 Game counts 5814
# Iteration 1441034	Training step 357759/4000000  Mean Max Q 0.974747 last_episode_reward 1 Game counts 5815
# Iteration 1441345	Training step 357837/4000000  Mean Max Q 1.080797 last_episode_reward 3 Game counts 5816
# Iteration 1441515	Training step 357879/4000000  Mean Max Q 1.016843 last_episode_reward 0 Game counts 5817
# Iteration 1441782	Training step 357946/4000000  Mean Max Q 1.065481 last_episode_reward 2 Game counts 5818
# Iteration 1441946	Training step 357987/4000000  Mean Max Q 1.013185 last_episode_reward 0 Game counts 5819
# Iteration 1442215	Training step 358054/4000000  Mean Max Q 1.044931 last_episode_reward 2 Game counts 5820
# Iteration 1442378	Training step 358095/4000000  Mean Max Q 1.014963 last_episode_reward 0 Game counts 5821
# Iteration 1442542	Training step 358136/4000000  Mean Max Q 1.000577 last_episode_reward 0 Game counts 5822
# Iteration 1442751	Training step 358188/4000000  Mean Max Q 1.054239 last_episode_reward 1 Game counts 5823
# Iteration 1443091	Training step 358273/4000000  Mean Max Q 1.057414 last_episode_reward 3 Game counts 5824
# Iteration 1443359	Training step 358340/4000000  Mean Max Q 0.948493 last_episode_reward 2 Game counts 5825
# Iteration 1443540	Training step 358385/4000000  Mean Max Q 1.009257 last_episode_reward 0 Game counts 5826
# Iteration 1443699	Training step 358425/4000000  Mean Max Q 1.003232 last_episode_reward 0 Game counts 5827
# Iteration 1443974	Training step 358494/4000000  Mean Max Q 1.105368 last_episode_reward 2 Game counts 5828
# Iteration 1444292	Training step 358573/4000000  Mean Max Q 1.032268 last_episode_reward 3 Game counts 5829
# Iteration 1444564	Training step 358641/4000000  Mean Max Q 1.139986 last_episode_reward 2 Game counts 5830
# Iteration 1444895	Training step 358724/4000000  Mean Max Q 1.047868 last_episode_reward 3 Game counts 5831
# Iteration 1445202	Training step 358801/4000000  Mean Max Q 1.020291 last_episode_reward 2 Game counts 5832
# Iteration 1445400	Training step 358850/4000000  Mean Max Q 1.036759 last_episode_reward 1 Game counts 5833
# Iteration 1445634	Training step 358909/4000000  Mean Max Q 0.992359 last_episode_reward 1 Game counts 5834
# Iteration 1445965	Training step 358992/4000000  Mean Max Q 0.989309 last_episode_reward 3 Game counts 5835
# Iteration 1446253	Training step 359064/4000000  Mean Max Q 1.077868 last_episode_reward 2 Game counts 5836
# Iteration 1446424	Training step 359106/4000000  Mean Max Q 1.021260 last_episode_reward 0 Game counts 5837
# Iteration 1446768	Training step 359192/4000000  Mean Max Q 1.005883 last_episode_reward 3 Game counts 5838
# Iteration 1446933	Training step 359234/4000000  Mean Max Q 1.031295 last_episode_reward 0 Game counts 5839
# Iteration 1447164	Training step 359291/4000000  Mean Max Q 1.110955 last_episode_reward 1 Game counts 5840
# Iteration 1447333	Training step 359334/4000000  Mean Max Q 1.020864 last_episode_reward 0 Game counts 5841
# Iteration 1447540	Training step 359385/4000000  Mean Max Q 0.904269 last_episode_reward 1 Game counts 5842
# Iteration 1447806	Training step 359452/4000000  Mean Max Q 0.881888 last_episode_reward 2 Game counts 5843
# Iteration 1448108	Training step 359527/4000000  Mean Max Q 1.155851 last_episode_reward 3 Game counts 5844
# Iteration 1448278	Training step 359570/4000000  Mean Max Q 1.018564 last_episode_reward 0 Game counts 5845
# Iteration 1448589	Training step 359648/4000000  Mean Max Q 1.088516 last_episode_reward 3 Game counts 5846
# Iteration 1448904	Training step 359726/4000000  Mean Max Q 0.865750 last_episode_reward 2 Game counts 5847
# Iteration 1449082	Training step 359771/4000000  Mean Max Q 1.026719 last_episode_reward 0 Game counts 5848
# Iteration 1449310	Training step 359828/4000000  Mean Max Q 1.006062 last_episode_reward 1 Game counts 5849
# Iteration 1449537	Training step 359885/4000000  Mean Max Q 1.054881 last_episode_reward 1 Game counts 5850
# Iteration 1449804	Training step 359951/4000000  Mean Max Q 1.064979 last_episode_reward 2 Game counts 5851
# Iteration 1450010	Training step 360003/4000000  Mean Max Q 0.946639 last_episode_reward 1 Game counts 5852
# Iteration 1450272	Training step 360068/4000000  Mean Max Q 0.963624 last_episode_reward 2 Game counts 5853
# Iteration 1450542	Training step 360136/4000000  Mean Max Q 1.098841 last_episode_reward 2 Game counts 5854
# Iteration 1450771	Training step 360193/4000000  Mean Max Q 1.091631 last_episode_reward 1 Game counts 5855
# Iteration 1451290	Training step 360323/4000000  Mean Max Q 0.996069 last_episode_reward 6 Game counts 5856
# Iteration 1451467	Training step 360367/4000000  Mean Max Q 1.021474 last_episode_reward 0 Game counts 5857
# Iteration 1451704	Training step 360426/4000000  Mean Max Q 1.164117 last_episode_reward 1 Game counts 5858
# Iteration 1452010	Training step 360503/4000000  Mean Max Q 1.073058 last_episode_reward 2 Game counts 5859
# Iteration 1452180	Training step 360545/4000000  Mean Max Q 1.017988 last_episode_reward 0 Game counts 5860
# Iteration 1452351	Training step 360588/4000000  Mean Max Q 1.025167 last_episode_reward 0 Game counts 5861
# Iteration 1452589	Training step 360648/4000000  Mean Max Q 1.063586 last_episode_reward 1 Game counts 5862
# Iteration 1452843	Training step 360711/4000000  Mean Max Q 1.096546 last_episode_reward 2 Game counts 5863
# Iteration 1453011	Training step 360753/4000000  Mean Max Q 1.002042 last_episode_reward 0 Game counts 5864
# Iteration 1453181	Training step 360796/4000000  Mean Max Q 1.029536 last_episode_reward 0 Game counts 5865
# Iteration 1453418	Training step 360855/4000000  Mean Max Q 1.100154 last_episode_reward 1 Game counts 5866
# Iteration 1453630	Training step 360908/4000000  Mean Max Q 0.824468 last_episode_reward 1 Game counts 5867
# Iteration 1453879	Training step 360970/4000000  Mean Max Q 0.981003 last_episode_reward 1 Game counts 5868
# Iteration 1454213	Training step 361054/4000000  Mean Max Q 0.998867 last_episode_reward 3 Game counts 5869
# Iteration 1454638	Training step 361160/4000000  Mean Max Q 0.877326 last_episode_reward 5 Game counts 5870
# Iteration 1454800	Training step 361200/4000000  Mean Max Q 1.011666 last_episode_reward 0 Game counts 5871
# Iteration 1455182	Training step 361296/4000000  Mean Max Q 0.854206 last_episode_reward 4 Game counts 5872
# Iteration 1455346	Training step 361337/4000000  Mean Max Q 1.025860 last_episode_reward 0 Game counts 5873
# Iteration 1455514	Training step 361379/4000000  Mean Max Q 1.018020 last_episode_reward 0 Game counts 5874
# Iteration 1455683	Training step 361421/4000000  Mean Max Q 1.018584 last_episode_reward 0 Game counts 5875
# Iteration 1456027	Training step 361507/4000000  Mean Max Q 1.014699 last_episode_reward 3 Game counts 5876
# Iteration 1456254	Training step 361564/4000000  Mean Max Q 1.170656 last_episode_reward 1 Game counts 5877
# Iteration 1456416	Training step 361604/4000000  Mean Max Q 1.027459 last_episode_reward 0 Game counts 5878
# Iteration 1456914	Training step 361729/4000000  Mean Max Q 1.148410 last_episode_reward 5 Game counts 5879
# Iteration 1457126	Training step 361782/4000000  Mean Max Q 0.820048 last_episode_reward 1 Game counts 5880
# Iteration 1457293	Training step 361824/4000000  Mean Max Q 1.001618 last_episode_reward 0 Game counts 5881
# Iteration 1457687	Training step 361922/4000000  Mean Max Q 0.887553 last_episode_reward 4 Game counts 5882
# Iteration 1457954	Training step 361989/4000000  Mean Max Q 0.922190 last_episode_reward 2 Game counts 5883
# Iteration 1458129	Training step 362033/4000000  Mean Max Q 1.009195 last_episode_reward 0 Game counts 5884
# Iteration 1458352	Training step 362088/4000000  Mean Max Q 0.961795 last_episode_reward 1 Game counts 5885
# Iteration 1458585	Training step 362147/4000000  Mean Max Q 1.083524 last_episode_reward 1 Game counts 5886
# Iteration 1458850	Training step 362213/4000000  Mean Max Q 1.058550 last_episode_reward 2 Game counts 5887
# Iteration 1459012	Training step 362253/4000000  Mean Max Q 1.011656 last_episode_reward 0 Game counts 5888
# Iteration 1459232	Training step 362308/4000000  Mean Max Q 1.032989 last_episode_reward 1 Game counts 5889
# Iteration 1459400	Training step 362350/4000000  Mean Max Q 0.995300 last_episode_reward 0 Game counts 5890
# Iteration 1459608	Training step 362402/4000000  Mean Max Q 0.904210 last_episode_reward 1 Game counts 5891
# Iteration 1459815	Training step 362454/4000000  Mean Max Q 1.071022 last_episode_reward 1 Game counts 5892
# Iteration 1459998	Training step 362500/4000000  Mean Max Q 1.003175 last_episode_reward 0 Game counts 5893
# Iteration 1460236	Training step 362559/4000000  Mean Max Q 1.011394 last_episode_reward 1 Game counts 5894
# Iteration 1460613	Training step 362654/4000000  Mean Max Q 1.066698 last_episode_reward 4 Game counts 5895
# Iteration 1460817	Training step 362705/4000000  Mean Max Q 1.131530 last_episode_reward 1 Game counts 5896
# Iteration 1461129	Training step 362783/4000000  Mean Max Q 1.100876 last_episode_reward 2 Game counts 5897
# Iteration 1461459	Training step 362865/4000000  Mean Max Q 1.066604 last_episode_reward 3 Game counts 5898
# Iteration 1461786	Training step 362947/4000000  Mean Max Q 1.191771 last_episode_reward 3 Game counts 5899
# Iteration 1461992	Training step 362998/4000000  Mean Max Q 0.983640 last_episode_reward 1 Game counts 5900
# Iteration 1462164	Training step 363041/4000000  Mean Max Q 1.005145 last_episode_reward 0 Game counts 5901
# Iteration 1462618	Training step 363155/4000000  Mean Max Q 0.745341 last_episode_reward 5 Game counts 5902
# Iteration 1462850	Training step 363213/4000000  Mean Max Q 1.064028 last_episode_reward 1 Game counts 5903
# Iteration 1463026	Training step 363257/4000000  Mean Max Q 1.018942 last_episode_reward 0 Game counts 5904
# Iteration 1463342	Training step 363336/4000000  Mean Max Q 1.009311 last_episode_reward 3 Game counts 5905
# Iteration 1463608	Training step 363402/4000000  Mean Max Q 0.995736 last_episode_reward 2 Game counts 5906
# Iteration 1463905	Training step 363477/4000000  Mean Max Q 1.023087 last_episode_reward 2 Game counts 5907
# Iteration 1464242	Training step 363561/4000000  Mean Max Q 1.046564 last_episode_reward 3 Game counts 5908
# Iteration 1464472	Training step 363618/4000000  Mean Max Q 0.949045 last_episode_reward 1 Game counts 5909
# Iteration 1464641	Training step 363661/4000000  Mean Max Q 1.004498 last_episode_reward 0 Game counts 5910
# Iteration 1464867	Training step 363717/4000000  Mean Max Q 1.099931 last_episode_reward 1 Game counts 5911
# Iteration 1465095	Training step 363774/4000000  Mean Max Q 1.092453 last_episode_reward 1 Game counts 5912
# Iteration 1465430	Training step 363858/4000000  Mean Max Q 0.929233 last_episode_reward 3 Game counts 5913
# Iteration 1465680	Training step 363920/4000000  Mean Max Q 0.894321 last_episode_reward 2 Game counts 5914
# Iteration 1465923	Training step 363981/4000000  Mean Max Q 0.839607 last_episode_reward 2 Game counts 5915
# Iteration 1466285	Training step 364072/4000000  Mean Max Q 0.850653 last_episode_reward 3 Game counts 5916
# Iteration 1466545	Training step 364137/4000000  Mean Max Q 1.087955 last_episode_reward 2 Game counts 5917
# Iteration 1466749	Training step 364188/4000000  Mean Max Q 1.043366 last_episode_reward 1 Game counts 5918
# Iteration 1467042	Training step 364261/4000000  Mean Max Q 1.147749 last_episode_reward 2 Game counts 5919
# Iteration 1467215	Training step 364304/4000000  Mean Max Q 0.990358 last_episode_reward 0 Game counts 5920
# Iteration 1467488	Training step 364372/4000000  Mean Max Q 1.144351 last_episode_reward 2 Game counts 5921
# Iteration 1467748	Training step 364437/4000000  Mean Max Q 0.970367 last_episode_reward 2 Game counts 5922
# Iteration 1468058	Training step 364515/4000000  Mean Max Q 1.032430 last_episode_reward 3 Game counts 5923
# Iteration 1468398	Training step 364600/4000000  Mean Max Q 1.012005 last_episode_reward 3 Game counts 5924
# Iteration 1468615	Training step 364654/4000000  Mean Max Q 0.969391 last_episode_reward 1 Game counts 5925
