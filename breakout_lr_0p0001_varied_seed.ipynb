# %% [markdown]
# <a href="https://colab.research.google.com/github/jiedali/colab_temp/blob/main/breakout_lr_0p0001_varied_seed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
# Reference: https://www.cs.toronto.edu/~vmnih/docs/dqn.pdf
import os
import time
import numpy as np
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
import gym
import random
from collections import deque
import matplotlib.pyplot as plt
# choose a GPU card
os.environ['CUDA_VISIBLE_DEVICES']="0"
# Set seed for tensorflow
SEED=1
tf.set_random_seed(SEED)
GYM_SEED=567
# Out:
# 1.15.2

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
env = gym.make("Breakout-v0")
obs = env.reset()
env.seed(GYM_SEED)
obs.shape
# Out:
# (210, 160, 3)

# %%
### Helper Functions

# %%
def preprocess(image):
    """ prepro 210x160x3 uint8 frame into 6400 (80x80) 2D float array """
    image = image[35:195] # crop
    image = image[::2,::2,0] # downsample by factor of 2
    image[image == 144] = 0 # erase background (background type 1)
    image[image == 109] = 0 # erase background (background type 2)
    image[image != 0] = 1 # everything else just set to 1
    return np.reshape(image.astype(np.float).ravel(), [80,80])

# %% [markdown]
# ## Define Q network

# %%
# This is now exactly the same as Ghani's CNN settings
# need to adjust to 80**)
state_size=[80,80,1]
action_size=env.action_space.n
n_outputs=action_size 
input_height=80
input_width=80
input_channels=1

# %%
learning_rate=0.0001
# Use adam optimizer
beta_1=0.9
beta_2=0.999
epsilon=1e-07

# %%
# Define a Q network with input size of [80,80], and an output size of size of action space 2
# Note that the action space is 4 with following meanings:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']
# We will only be taking action 2 or 3
class DQN(object):
    def __init__(self, state_size, action_size, learning_rate, name='online_q_network'):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate
        self.name =name
        
        with tf.variable_scope(name):
            with tf.name_scope("inputs"):
                # Jieda note: state is preprocessd 80*80*1 array
                self.inputs = tf.placeholder(tf.float32, [None,*state_size], name = "inputs")

            with tf.name_scope("conv1"):
                self.conv1 = tf.layers.conv2d(
                inputs=self.inputs, filters=32, kernel_size=[8, 8], strides=4,
                kernel_initializer=tf.variance_scaling_initializer(scale=2),
                padding="VALID", activation=tf.nn.relu, use_bias=False, name='conv1')
                
                self.conv1_out = tf.nn.relu(self.conv1, name='conv1_out')
             
            with tf.name_scope("conv2"):
                
                self.conv2 = tf.layers.conv2d(
                inputs = self.conv1_out, filters=64,
                kernel_size=[4,4], strides=[2,2],padding="VALID",
                kernel_initializer = tf.variance_scaling_initializer(scale=2),
                activation=tf.nn.relu, use_bias=False, name='conv2')
                
                self.conv2_out = tf.nn.relu(self.conv2, name='conv2_out')
            
            with tf.name_scope("conv3"):
            
                self.conv3 = tf.layers.conv2d(
                inputs = self.conv2_out, filters=64,
                 kernel_size=[3,3], strides=[1,1], padding="VALID",
                 kernel_initializer = tf.variance_scaling_initializer(scale=2),
                 name = "conv3")
                
                self.conv3_out = tf.nn.relu(self.conv3, name='conv3_out')
            
            with tf.name_scope("flatten"):
                self.flatten = tf.contrib.layers.flatten(self.conv3_out)
                

            with tf.name_scope("fc1"):
                self.fc1 = tf.layers.dense(inputs=self.flatten,
                                          units = 512, activation = tf.nn.relu,
                                          kernel_initializer = tf.contrib.layers.xavier_initializer(), name = "fc1")
            
            with tf.name_scope("fc1"):
                self.fc2 = tf.layers.dense(inputs=self.flatten,
                                          units = 512, activation = tf.nn.relu,
                                          kernel_initializer = tf.contrib.layers.xavier_initializer(), name = "fc2")

            with tf.name_scope("outputs"):
                self.outputs = tf.layers.dense(inputs = self.fc2,
                                              units = action_size,
                                              kernel_initializer = tf.contrib.layers.xavier_initializer(),
                                              activation = None)
            # Output is the approximated Action Values Q(s,a), so we don't need any activation 

    def get_outputs(self):
      
        return self.outputs

    def get_weights(self,scope_name):
        # give all the weights of that network
        trainable_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=scope_name)
        # create a dictionary to contain the values of the network weights
        trainable_vars_by_name = {var.name[len(scope_name):]: var
                                for var in trainable_vars}
        return trainable_vars_by_name  

#
tf.reset_default_graph()
X_state=tf.placeholder(tf.float32,shape=[None,input_height,input_width,input_channels])
# initialize the two Q network
online_q = DQN(state_size, action_size, learning_rate, 'online_q_network')
target_q = DQN(state_size, action_size, learning_rate, 'target_q_network')
# get the output and weights from online q network
online_q_values=online_q.get_outputs()
online_q_weights=online_q.get_weights(scope_name='online_q_network')
# # get the output and weights from target q network
target_q_values=target_q.get_outputs()
target_q_weights=target_q.get_weights(scope_name='target_q_network')
# define the operation to copy the online network weights to target_q_network weights
copy_ops = [target_var.assign(online_q_weights[var_name]) for var_name, target_var in target_q_weights.items()]
#
copy_online_to_target = tf.group(*copy_ops)

## define the train operation
with tf.variable_scope("train"):
  # define training operation
  input_action = tf.placeholder(tf.int32, shape=[None])
  y=tf.placeholder(tf.float32, shape=[None, 1])
  # Get the Q values for the input_action
  q_value = tf.reduce_sum(online_q_values*tf.one_hot(input_action,action_size),axis=1,keepdims=True)
  # compute the error between lable y and q_value from online_q_network approximation
  # Note that lable y is computed using the target_q_network
  error=tf.abs(y-q_value)
  clipped_error = tf.clip_by_value(error,0,1)
  linear_error = 2*(error-clipped_error)
  loss = tf.reduce_mean(tf.square(clipped_error)+linear_error)

  # global_step is used to keep track of number of training steps completed
  global_step = tf.Variable(0,trainable=False,name='global_step')
  optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=0.9, beta2=0.999,epsilon=1e-08,use_locking=False,name='Adam')
  training_op = optimizer.minimize(loss, global_step=global_step)

init=tf.global_variables_initializer()
saver=tf.train.Saver()

# %%
# reduced replay buffer size (see if it can avoid the RAM crashing issue)
replay_memory_size=20000
# replay_memory = deque([],maxlen=replay_memory_size)

class ReplayBuffer:
    def __init__(self,maxlen):
        self.maxlen=maxlen
        self.buf = np.empty(shape=maxlen, dtype=np.object)
        self.index=0
        self.length=0

    def append(self, data):
        self.buf[self.index] = data
        self.length = min(self.length+1, self.maxlen)
        self.index = (self.index + 1) % self.maxlen
    
    def sample(self, batch_size):
        # sample without replacement
        indices = np.random.permutation(self.length)[:batch_size]
        return self.buf[indices]

# create an instance of ReplayBuffer
replay_buffer = ReplayBuffer(replay_memory_size)
def sample_replay_buffer(batch_size):
  cols =[[],[],[],[],[]] # state, action, reward, next_state, continue
  for memory in replay_buffer.sample(batch_size):
    for col, value in zip(cols, memory):
      col.append(value)
  cols = [np.array(col) for col in cols]
  return cols[0], cols[1], cols[2].reshape(-1,1), cols[3], cols[4].reshape(-1,1)

# %%
replay_buffer = ReplayBuffer(replay_memory_size)
memory = replay_buffer.sample(2)
memory
# Out:
# array([], dtype=object)

# %%
## Epsilon Greedy

# %%
eps_min = 0.1
eps_max = 1.0
eps_decay_steps = 2000000
def epsilon_greedy(q_values, step):
    # Note: we gradually decrease epsilon, we explore more in the beginning, less towards later
    epsilon = max(eps_min, eps_max-(eps_max-eps_min)*step/eps_decay_steps)
    if np.random.rand()<epsilon:
        return np.random.randint(n_outputs)
    else:
        return np.argmax(q_values)

# %%
## Training parameters

# %%
# checkpoint path
checkpoint_path="./breakout_dqn.ckpt"
# This is the number of training steps 
n_steps = 4000000
# In the very beginning, First have 10000 samples in the replay buffer
training_start=10000
# Before each training step, we run 4 episodes and add those samples to replay buffer
training_interval=4
# 
save_steps=1000
copy_steps = 2500 # copy the online network parameters to target network every 10000 steps
discount_rate=0.99
skip_start=90
batch_size=50
iteration=0
done=True
# initialize the tracking statistics
max_episode_reward_so_far=0
total_max_q=-float('inf')
mean_reward=0
total_reward=0
game_length=0
game_counter=0

# %%
obs, reward, done, info = env.step(0)
state = preprocess(obs)
state=state.reshape(80,80,1)
state.shape
# Out:
# (80, 80, 1)

# %%
with tf.Session() as sess:
  # if os.path.isfile(checkpoint_path +".index"):
  #   saver.restore(sess, checkpoint_path)
  # else:
  init.run()
  # to make sure they have the same values to begin with
  # otherwise, different seeds will result in different initialized network weights
  copy_online_to_target.run()
  # intialize replay buffer
  replay_buffer = ReplayBuffer(replay_memory_size)
  # start training
  # Training loop : 
  # (1) collect M data points, add to replay buffer (play 4 episodes of game, add those to replay buffer)
  # (2) copy online network parameter to target network
  # (3) sample a batch from replay buffer, do the online network update (batch size:50)
  while True:
    step = global_step.eval()
    # if global training steps have meet the maximum, we will stop training
    if step >= n_steps:
      break
    # One iteration is just one sample generation !!!
    iteration+=1
    if done:
      obs = env.reset()
      for skip in range(skip_start): # skip the beginning of each game
        obs, reward, done, info = env.step(0) # take action 0
      state = preprocess(obs)
    state = state.reshape(1,80,80,1)
    state_to_rb=state.reshape(80,80,1)
      
    # online network evaluates what to do
    q_values = online_q_values.eval(feed_dict={online_q.inputs:state})
    # q_values returns array of 4 values corresponding to 4 actions
    # for each step in the game, we record the max of q_values 
    action = epsilon_greedy(q_values,step)

    # online network plays
    obs, reward, done, info = env.step(action)
    next_state = preprocess(obs)
    next_state = next_state.reshape(1,80,80,1)
    next_state_to_rb = next_state.reshape(80,80,1)

    # Add this sample to the replay buffer
    replay_buffer.append((state_to_rb, action, reward, next_state_to_rb, 1.0-done))
    # pass "next_state" to "state"
    state=next_state
    state_to_rb=next_state_to_rb

    # compute statistics to track training progress
    # track the maximum episode reward obtained so far, and the average episode reward
    total_reward += reward
    total_max_q += q_values.max()
    game_length +=1
    if done:
      game_counter +=1
      mean_max_q = total_max_q/game_length
      mean_reward = total_reward/game_length
      if total_reward > max_episode_reward_so_far:
        max_episode_reward_so_far = total_reward
      total_max_q=0.0
      game_length = 0
      total_reward=0

    # if number of samples are less than training_start(10000), or it is not a multiple of 4, we will NOT do training
    if iteration < training_start or iteration % training_interval !=0:
      continue
    
    if iteration % 1000 == 0: # print stats every 100 training steps
      print("Iteration %d\tTraining step %d/%d  Mean Max Q %f episode total reward %d  Max episode reward so far %d  Game length %d  Game counts %d" %(iteration, step, n_steps, mean_max_q, total_reward, max_episode_reward_so_far, game_length, game_counter))
    # otherwise, if iteration is more than 10,000 and it is a multiple of 4, we will update the network
    # result=sample_replay_buffer(batch_size)
    X_state_val, X_action_val, rewards, X_next_state_val, continues = sample_replay_buffer(batch_size)
    #
    next_q_values = target_q_values.eval(
        feed_dict = {target_q.inputs: X_next_state_val}
    )
    max_next_q_values = np.max(next_q_values, axis=1, keepdims=True)
    y_val = rewards + continues*discount_rate*max_next_q_values

    # train online q network
    _, loss_val = sess.run([training_op,loss], feed_dict={online_q.inputs:X_state_val, input_action: X_action_val, y:y_val})

    # copy online q network to target network
    if step % copy_steps ==0:
      copy_online_to_target.run()
    
    # save dqn regularly
    if step % save_steps ==0:
      saver.save(sess,checkpoint_path)
# Out:
# Iteration 10000	Training step 0/4000000  Mean Max Q 0.961389 episode total reward 0  Max episode reward so far 8  Game length 70  Game counts 42
# Iteration 11000	Training step 250/4000000  Mean Max Q 0.937874 episode total reward 2  Max episode reward so far 8  Game length 250  Game counts 46
# Iteration 12000	Training step 500/4000000  Mean Max Q 0.933432 episode total reward 0  Max episode reward so far 8  Game length 48  Game counts 51
# Iteration 13000	Training step 750/4000000  Mean Max Q 0.915748 episode total reward 2  Max episode reward so far 8  Game length 181  Game counts 55
# Iteration 14000	Training step 1000/4000000  Mean Max Q 0.929881 episode total reward 2  Max episode reward so far 8  Game length 155  Game counts 59
# Iteration 15000	Training step 1250/4000000  Mean Max Q 0.943871 episode total reward 0  Max episode reward so far 8  Game length 44  Game counts 63
# Iteration 16000	Training step 1500/4000000  Mean Max Q 0.933640 episode total reward 0  Max episode reward so far 8  Game length 62  Game counts 67
# Iteration 17000	Training step 1750/4000000  Mean Max Q 0.938787 episode total reward 0  Max episode reward so far 8  Game length 32  Game counts 71
# Iteration 18000	Training step 2000/4000000  Mean Max Q 0.930736 episode total reward 0  Max episode reward so far 8  Game length 117  Game counts 74
# Iteration 19000	Training step 2250/4000000  Mean Max Q 0.938877 episode total reward 0  Max episode reward so far 8  Game length 181  Game counts 78
# Iteration 20000	Training step 2500/4000000  Mean Max Q 0.916119 episode total reward 1  Max episode reward so far 8  Game length 99  Game counts 83
# Iteration 21000	Training step 2750/4000000  Mean Max Q 0.900047 episode total reward 0  Max episode reward so far 8  Game length 21  Game counts 87
# Iteration 22000	Training step 3000/4000000  Mean Max Q 0.890637 episode total reward 0  Max episode reward so far 8  Game length 62  Game counts 92
# Iteration 23000	Training step 3250/4000000  Mean Max Q 0.861178 episode total reward 1  Max episode reward so far 8  Game length 96  Game counts 96
# Iteration 24000	Training step 3500/4000000  Mean Max Q 0.905519 episode total reward 1  Max episode reward so far 8  Game length 162  Game counts 99
# Iteration 25000	Training step 3750/4000000  Mean Max Q 0.908886 episode total reward 2  Max episode reward so far 8  Game length 277  Game counts 103
# Iteration 26000	Training step 4000/4000000  Mean Max Q 0.919376 episode total reward 1  Max episode reward so far 8  Game length 221  Game counts 107
# Iteration 27000	Training step 4250/4000000  Mean Max Q 0.911214 episode total reward 0  Max episode reward so far 8  Game length 110  Game counts 112
# Iteration 28000	Training step 4500/4000000  Mean Max Q 0.903492 episode total reward 0  Max episode reward so far 8  Game length 165  Game counts 116
# Iteration 29000	Training step 4750/4000000  Mean Max Q 0.894095 episode total reward 0  Max episode reward so far 8  Game length 76  Game counts 120
# Iteration 30000	Training step 5000/4000000  Mean Max Q 0.900399 episode total reward 0  Max episode reward so far 8  Game length 113  Game counts 125
# Iteration 31000	Training step 5250/4000000  Mean Max Q 0.921056 episode total reward 1  Max episode reward so far 8  Game length 214  Game counts 128
# Iteration 32000	Training step 5500/4000000  Mean Max Q 0.941855 episode total reward 1  Max episode reward so far 8  Game length 82  Game counts 133
# Iteration 33000	Training step 5750/4000000  Mean Max Q 0.953276 episode total reward 0  Max episode reward so far 8  Game length 176  Game counts 136
# Iteration 34000	Training step 6000/4000000  Mean Max Q 0.929961 episode total reward 3  Max episode reward so far 8  Game length 286  Game counts 139
# Iteration 35000	Training step 6250/4000000  Mean Max Q 0.931233 episode total reward 0  Max episode reward so far 8  Game length 44  Game counts 143
# Iteration 36000	Training step 6500/4000000  Mean Max Q 0.904919 episode total reward 0  Max episode reward so far 8  Game length 45  Game counts 147
# Iteration 37000	Training step 6750/4000000  Mean Max Q 0.927739 episode total reward 0  Max episode reward so far 8  Game length 1  Game counts 151
# Iteration 38000	Training step 7000/4000000  Mean Max Q 0.832163 episode total reward 1  Max episode reward so far 8  Game length 229  Game counts 153
# Iteration 39000	Training step 7250/4000000  Mean Max Q 0.939707 episode total reward 0  Max episode reward so far 8  Game length 42  Game counts 157
# Iteration 40000	Training step 7500/4000000  Mean Max Q 0.931636 episode total reward 0  Max episode reward so far 8  Game length 34  Game counts 161
# Iteration 41000	Training step 7750/4000000  Mean Max Q 0.974064 episode total reward 2  Max episode reward so far 8  Game length 249  Game counts 164
# Iteration 42000	Training step 8000/4000000  Mean Max Q 0.974207 episode total reward 0  Max episode reward so far 8  Game length 141  Game counts 169
# Iteration 43000	Training step 8250/4000000  Mean Max Q 0.981943 episode total reward 0  Max episode reward so far 8  Game length 147  Game counts 174
# Iteration 44000	Training step 8500/4000000  Mean Max Q 0.973761 episode total reward 0  Max episode reward so far 8  Game length 174  Game counts 178
# Iteration 45000	Training step 8750/4000000  Mean Max Q 0.946232 episode total reward 0  Max episode reward so far 8  Game length 51  Game counts 183
# Iteration 46000	Training step 9000/4000000  Mean Max Q 0.970126 episode total reward 0  Max episode reward so far 8  Game length 38  Game counts 187
# Iteration 47000	Training step 9250/4000000  Mean Max Q 1.056170 episode total reward 0  Max episode reward so far 8  Game length 41  Game counts 190
# Iteration 48000	Training step 9500/4000000  Mean Max Q 0.968540 episode total reward 1  Max episode reward so far 8  Game length 202  Game counts 193
# Iteration 49000	Training step 9750/4000000  Mean Max Q 0.912355 episode total reward 0  Max episode reward so far 8  Game length 37  Game counts 197
# Iteration 50000	Training step 10000/4000000  Mean Max Q 0.975690 episode total reward 0  Max episode reward so far 8  Game length 28  Game counts 202
# Iteration 51000	Training step 10250/4000000  Mean Max Q 1.153499 episode total reward 1  Max episode reward so far 8  Game length 178  Game counts 205
# Iteration 52000	Training step 10500/4000000  Mean Max Q 1.008239 episode total reward 2  Max episode reward so far 8  Game length 192  Game counts 209
# Iteration 53000	Training step 10750/4000000  Mean Max Q 0.989749 episode total reward 2  Max episode reward so far 8  Game length 231  Game counts 213
# Iteration 54000	Training step 11000/4000000  Mean Max Q 1.017167 episode total reward 0  Max episode reward so far 8  Game length 41  Game counts 218
# Iteration 55000	Training step 11250/4000000  Mean Max Q 0.980560 episode total reward 0  Max episode reward so far 8  Game length 60  Game counts 221
# Iteration 56000	Training step 11500/4000000  Mean Max Q 0.979797 episode total reward 0  Max episode reward so far 8  Game length 67  Game counts 226
# Iteration 57000	Training step 11750/4000000  Mean Max Q 1.012960 episode total reward 1  Max episode reward so far 8  Game length 176  Game counts 230
# Iteration 58000	Training step 12000/4000000  Mean Max Q 0.994746 episode total reward 1  Max episode reward so far 8  Game length 174  Game counts 234
# Iteration 59000	Training step 12250/4000000  Mean Max Q 0.998855 episode total reward 1  Max episode reward so far 8  Game length 208  Game counts 238
# Iteration 60000	Training step 12500/4000000  Mean Max Q 0.998876 episode total reward 2  Max episode reward so far 8  Game length 153  Game counts 242
# Iteration 61000	Training step 12750/4000000  Mean Max Q 0.937088 episode total reward 3  Max episode reward so far 8  Game length 298  Game counts 244
# Iteration 62000	Training step 13000/4000000  Mean Max Q 1.070791 episode total reward 0  Max episode reward so far 8  Game length 0  Game counts 249
# Iteration 63000	Training step 13250/4000000  Mean Max Q 0.996926 episode total reward 0  Max episode reward so far 8  Game length 80  Game counts 253
# Iteration 64000	Training step 13500/4000000  Mean Max Q 0.979134 episode total reward 0  Max episode reward so far 8  Game length 56  Game counts 257
# Iteration 65000	Training step 13750/4000000  Mean Max Q 1.010674 episode total reward 0  Max episode reward so far 8  Game length 20  Game counts 260
# Iteration 66000	Training step 14000/4000000  Mean Max Q 0.986512 episode total reward 3  Max episode reward so far 8  Game length 168  Game counts 264
# Iteration 67000	Training step 14250/4000000  Mean Max Q 0.952579 episode total reward 0  Max episode reward so far 8  Game length 4  Game counts 268
# Iteration 68000	Training step 14500/4000000  Mean Max Q 0.968164 episode total reward 2  Max episode reward so far 8  Game length 202  Game counts 271
# Iteration 69000	Training step 14750/4000000  Mean Max Q 0.992072 episode total reward 0  Max episode reward so far 8  Game length 166  Game counts 275
# Iteration 70000	Training step 15000/4000000  Mean Max Q 0.993666 episode total reward 1  Max episode reward so far 8  Game length 179  Game counts 279
# Iteration 71000	Training step 15250/4000000  Mean Max Q 1.003071 episode total reward 0  Max episode reward so far 8  Game length 57  Game counts 284
# Iteration 72000	Training step 15500/4000000  Mean Max Q 1.004741 episode total reward 3  Max episode reward so far 8  Game length 301  Game counts 287
# Iteration 73000	Training step 15750/4000000  Mean Max Q 1.000480 episode total reward 0  Max episode reward so far 8  Game length 159  Game counts 291
# Iteration 74000	Training step 16000/4000000  Mean Max Q 1.028949 episode total reward 1  Max episode reward so far 8  Game length 130  Game counts 295
# Iteration 75000	Training step 16250/4000000  Mean Max Q 1.094229 episode total reward 0  Max episode reward so far 8  Game length 116  Game counts 298
# Iteration 76000	Training step 16500/4000000  Mean Max Q 1.002657 episode total reward 0  Max episode reward so far 8  Game length 153  Game counts 302
# Iteration 77000	Training step 16750/4000000  Mean Max Q 1.003948 episode total reward 0  Max episode reward so far 8  Game length 42  Game counts 307
# Iteration 78000	Training step 17000/4000000  Mean Max Q 0.984296 episode total reward 1  Max episode reward so far 8  Game length 235  Game counts 310
# Iteration 79000	Training step 17250/4000000  Mean Max Q 0.995726 episode total reward 1  Max episode reward so far 8  Game length 132  Game counts 315
# Iteration 80000	Training step 17500/4000000  Mean Max Q 1.015692 episode total reward 0  Max episode reward so far 8  Game length 59  Game counts 318
# Iteration 81000	Training step 17750/4000000  Mean Max Q 1.014244 episode total reward 0  Max episode reward so far 8  Game length 19  Game counts 322
# Iteration 82000	Training step 18000/4000000  Mean Max Q 1.013553 episode total reward 1  Max episode reward so far 8  Game length 172  Game counts 326
# Iteration 83000	Training step 18250/4000000  Mean Max Q 1.032872 episode total reward 0  Max episode reward so far 8  Game length 122  Game counts 331
# Iteration 84000	Training step 18500/4000000  Mean Max Q 1.019120 episode total reward 2  Max episode reward so far 8  Game length 178  Game counts 336
# Iteration 85000	Training step 18750/4000000  Mean Max Q 1.044364 episode total reward 2  Max episode reward so far 8  Game length 137  Game counts 340
# Iteration 86000	Training step 19000/4000000  Mean Max Q 0.997598 episode total reward 1  Max episode reward so far 8  Game length 193  Game counts 343
# Iteration 87000	Training step 19250/4000000  Mean Max Q 1.062539 episode total reward 0  Max episode reward so far 8  Game length 39  Game counts 347
# Iteration 88000	Training step 19500/4000000  Mean Max Q 1.007881 episode total reward 2  Max episode reward so far 8  Game length 207  Game counts 351
# Iteration 89000	Training step 19750/4000000  Mean Max Q 1.032882 episode total reward 1  Max episode reward so far 8  Game length 198  Game counts 354
# Iteration 90000	Training step 20000/4000000  Mean Max Q 0.972932 episode total reward 0  Max episode reward so far 8  Game length 118  Game counts 358
# Iteration 91000	Training step 20250/4000000  Mean Max Q 1.041815 episode total reward 1  Max episode reward so far 8  Game length 246  Game counts 362
# Iteration 92000	Training step 20500/4000000  Mean Max Q 1.014951 episode total reward 0  Max episode reward so far 8  Game length 63  Game counts 367
# Iteration 93000	Training step 20750/4000000  Mean Max Q 1.046541 episode total reward 0  Max episode reward so far 8  Game length 65  Game counts 371
# Iteration 94000	Training step 21000/4000000  Mean Max Q 1.017309 episode total reward 0  Max episode reward so far 8  Game length 71  Game counts 375
# Iteration 95000	Training step 21250/4000000  Mean Max Q 1.051476 episode total reward 0  Max episode reward so far 8  Game length 109  Game counts 379
# Iteration 96000	Training step 21500/4000000  Mean Max Q 0.997941 episode total reward 1  Max episode reward so far 8  Game length 215  Game counts 382
# Iteration 97000	Training step 21750/4000000  Mean Max Q 1.036898 episode total reward 1  Max episode reward so far 8  Game length 177  Game counts 387
# Iteration 98000	Training step 22000/4000000  Mean Max Q 0.971480 episode total reward 0  Max episode reward so far 8  Game length 50  Game counts 392
# Iteration 99000	Training step 22250/4000000  Mean Max Q 1.013134 episode total reward 0  Max episode reward so far 8  Game length 179  Game counts 396
# Iteration 100000	Training step 22500/4000000  Mean Max Q 1.056958 episode total reward 1  Max episode reward so far 8  Game length 72  Game counts 400
# Iteration 101000	Training step 22750/4000000  Mean Max Q 1.074807 episode total reward 1  Max episode reward so far 8  Game length 209  Game counts 403
# Iteration 102000	Training step 23000/4000000  Mean Max Q 1.094456 episode total reward 1  Max episode reward so far 8  Game length 181  Game counts 406
# Iteration 103000	Training step 23250/4000000  Mean Max Q 1.020002 episode total reward 2  Max episode reward so far 8  Game length 134  Game counts 410
# Iteration 104000	Training step 23500/4000000  Mean Max Q 1.078054 episode total reward 0  Max episode reward so far 8  Game length 100  Game counts 414
# Iteration 105000	Training step 23750/4000000  Mean Max Q 1.042581 episode total reward 2  Max episode reward so far 8  Game length 216  Game counts 418
# Iteration 106000	Training step 24000/4000000  Mean Max Q 1.019280 episode total reward 0  Max episode reward so far 8  Game length 159  Game counts 422
# Iteration 107000	Training step 24250/4000000  Mean Max Q 1.023175 episode total reward 0  Max episode reward so far 8  Game length 84  Game counts 427
# Iteration 108000	Training step 24500/4000000  Mean Max Q 1.031649 episode total reward 0  Max episode reward so far 8  Game length 7  Game counts 431
# Iteration 109000	Training step 24750/4000000  Mean Max Q 1.059478 episode total reward 4  Max episode reward so far 8  Game length 369  Game counts 433
# Iteration 110000	Training step 25000/4000000  Mean Max Q 1.117181 episode total reward 4  Max episode reward so far 8  Game length 364  Game counts 436
# Iteration 111000	Training step 25250/4000000  Mean Max Q 1.067494 episode total reward 0  Max episode reward so far 8  Game length 34  Game counts 441
# Iteration 112000	Training step 25500/4000000  Mean Max Q 1.019055 episode total reward 0  Max episode reward so far 8  Game length 76  Game counts 445
# Iteration 113000	Training step 25750/4000000  Mean Max Q 1.028459 episode total reward 0  Max episode reward so far 8  Game length 46  Game counts 450
# Iteration 114000	Training step 26000/4000000  Mean Max Q 1.022177 episode total reward 0  Max episode reward so far 8  Game length 53  Game counts 454
# Iteration 115000	Training step 26250/4000000  Mean Max Q 1.115807 episode total reward 2  Max episode reward so far 8  Game length 260  Game counts 458
# Iteration 116000	Training step 26500/4000000  Mean Max Q 1.083960 episode total reward 0  Max episode reward so far 8  Game length 142  Game counts 462
# Iteration 117000	Training step 26750/4000000  Mean Max Q 1.027652 episode total reward 0  Max episode reward so far 8  Game length 46  Game counts 467
# Iteration 118000	Training step 27000/4000000  Mean Max Q 1.038776 episode total reward 1  Max episode reward so far 8  Game length 166  Game counts 471
# Iteration 119000	Training step 27250/4000000  Mean Max Q 1.101319 episode total reward 1  Max episode reward so far 8  Game length 198  Game counts 475
# Iteration 120000	Training step 27500/4000000  Mean Max Q 1.120924 episode total reward 0  Max episode reward so far 8  Game length 154  Game counts 479
# Iteration 121000	Training step 27750/4000000  Mean Max Q 1.025709 episode total reward 0  Max episode reward so far 8  Game length 55  Game counts 484
# Iteration 122000	Training step 28000/4000000  Mean Max Q 1.021564 episode total reward 0  Max episode reward so far 8  Game length 127  Game counts 489
# Iteration 123000	Training step 28250/4000000  Mean Max Q 1.112634 episode total reward 0  Max episode reward so far 8  Game length 59  Game counts 493
# Iteration 124000	Training step 28500/4000000  Mean Max Q 1.027899 episode total reward 0  Max episode reward so far 8  Game length 85  Game counts 497
# Iteration 125000	Training step 28750/4000000  Mean Max Q 1.156548 episode total reward 4  Max episode reward so far 8  Game length 336  Game counts 500
# Iteration 126000	Training step 29000/4000000  Mean Max Q 1.017209 episode total reward 1  Max episode reward so far 8  Game length 129  Game counts 504
# Iteration 127000	Training step 29250/4000000  Mean Max Q 1.074377 episode total reward 0  Max episode reward so far 8  Game length 69  Game counts 509
# Iteration 128000	Training step 29500/4000000  Mean Max Q 1.083944 episode total reward 1  Max episode reward so far 8  Game length 195  Game counts 512
# Iteration 129000	Training step 29750/4000000  Mean Max Q 1.136886 episode total reward 1  Max episode reward so far 8  Game length 205  Game counts 516
# Iteration 130000	Training step 30000/4000000  Mean Max Q 1.066342 episode total reward 0  Max episode reward so far 8  Game length 37  Game counts 521
# Iteration 131000	Training step 30250/4000000  Mean Max Q 1.070525 episode total reward 0  Max episode reward so far 8  Game length 54  Game counts 525
# Iteration 132000	Training step 30500/4000000  Mean Max Q 1.015458 episode total reward 2  Max episode reward so far 8  Game length 241  Game counts 529
# Iteration 133000	Training step 30750/4000000  Mean Max Q 1.074890 episode total reward 1  Max episode reward so far 8  Game length 73  Game counts 534
# Iteration 134000	Training step 31000/4000000  Mean Max Q 1.116645 episode total reward 2  Max episode reward so far 8  Game length 198  Game counts 537
# Iteration 135000	Training step 31250/4000000  Mean Max Q 1.101810 episode total reward 3  Max episode reward so far 8  Game length 281  Game counts 541
# Iteration 136000	Training step 31500/4000000  Mean Max Q 1.018933 episode total reward 1  Max episode reward so far 8  Game length 72  Game counts 545
# Iteration 137000	Training step 31750/4000000  Mean Max Q 1.138399 episode total reward 2  Max episode reward so far 8  Game length 263  Game counts 547
# Iteration 138000	Training step 32000/4000000  Mean Max Q 1.115560 episode total reward 0  Max episode reward so far 8  Game length 16  Game counts 552
# Iteration 139000	Training step 32250/4000000  Mean Max Q 1.074302 episode total reward 0  Max episode reward so far 8  Game length 40  Game counts 556
# Iteration 140000	Training step 32500/4000000  Mean Max Q 1.107001 episode total reward 0  Max episode reward so far 8  Game length 123  Game counts 560
# Iteration 141000	Training step 32750/4000000  Mean Max Q 1.083901 episode total reward 2  Max episode reward so far 8  Game length 135  Game counts 565
# Iteration 142000	Training step 33000/4000000  Mean Max Q 1.099090 episode total reward 3  Max episode reward so far 8  Game length 264  Game counts 568
# Iteration 143000	Training step 33250/4000000  Mean Max Q 1.161187 episode total reward 0  Max episode reward so far 8  Game length 19  Game counts 572
# Iteration 144000	Training step 33500/4000000  Mean Max Q 1.061013 episode total reward 1  Max episode reward so far 8  Game length 162  Game counts 575
# Iteration 145000	Training step 33750/4000000  Mean Max Q 1.054844 episode total reward 0  Max episode reward so far 8  Game length 179  Game counts 579
# Iteration 146000	Training step 34000/4000000  Mean Max Q 1.016759 episode total reward 0  Max episode reward so far 8  Game length 21  Game counts 584
# Iteration 147000	Training step 34250/4000000  Mean Max Q 1.088208 episode total reward 4  Max episode reward so far 8  Game length 395  Game counts 586
# Iteration 148000	Training step 34500/4000000  Mean Max Q 1.142459 episode total reward 0  Max episode reward so far 8  Game length 180  Game counts 590
# Iteration 149000	Training step 34750/4000000  Mean Max Q 1.075750 episode total reward 0  Max episode reward so far 8  Game length 159  Game counts 594
# Iteration 150000	Training step 35000/4000000  Mean Max Q 1.075148 episode total reward 0  Max episode reward so far 8  Game length 4  Game counts 599
# Iteration 151000	Training step 35250/4000000  Mean Max Q 1.078480 episode total reward 0  Max episode reward so far 8  Game length 133  Game counts 603
# Iteration 152000	Training step 35500/4000000  Mean Max Q 1.060798 episode total reward 2  Max episode reward so far 8  Game length 165  Game counts 607
# Iteration 153000	Training step 35750/4000000  Mean Max Q 1.162999 episode total reward 1  Max episode reward so far 8  Game length 210  Game counts 611
# Iteration 154000	Training step 36000/4000000  Mean Max Q 1.027383 episode total reward 1  Max episode reward so far 8  Game length 171  Game counts 616
# Iteration 155000	Training step 36250/4000000  Mean Max Q 1.026743 episode total reward 3  Max episode reward so far 8  Game length 307  Game counts 620
# Iteration 156000	Training step 36500/4000000  Mean Max Q 1.092337 episode total reward 0  Max episode reward so far 8  Game length 62  Game counts 625
# Iteration 157000	Training step 36750/4000000  Mean Max Q 1.096459 episode total reward 0  Max episode reward so far 8  Game length 15  Game counts 629
# Iteration 158000	Training step 37000/4000000  Mean Max Q 1.016650 episode total reward 3  Max episode reward so far 8  Game length 316  Game counts 632
# Iteration 159000	Training step 37250/4000000  Mean Max Q 1.082851 episode total reward 7  Max episode reward so far 8  Game length 309  Game counts 636
# Iteration 160000	Training step 37500/4000000  Mean Max Q 1.021515 episode total reward 0  Max episode reward so far 8  Game length 121  Game counts 641
# Iteration 161000	Training step 37750/4000000  Mean Max Q 1.154632 episode total reward 0  Max episode reward so far 8  Game length 177  Game counts 644
# Iteration 162000	Training step 38000/4000000  Mean Max Q 1.122513 episode total reward 1  Max episode reward so far 8  Game length 215  Game counts 648
# Iteration 163000	Training step 38250/4000000  Mean Max Q 1.060821 episode total reward 0  Max episode reward so far 8  Game length 66  Game counts 653
# Iteration 164000	Training step 38500/4000000  Mean Max Q 1.142097 episode total reward 1  Max episode reward so far 8  Game length 145  Game counts 657
# Iteration 165000	Training step 38750/4000000  Mean Max Q 1.171323 episode total reward 0  Max episode reward so far 8  Game length 91  Game counts 661
# Iteration 166000	Training step 39000/4000000  Mean Max Q 1.054335 episode total reward 0  Max episode reward so far 8  Game length 113  Game counts 666
# Iteration 167000	Training step 39250/4000000  Mean Max Q 1.051440 episode total reward 3  Max episode reward so far 8  Game length 280  Game counts 669
# Iteration 168000	Training step 39500/4000000  Mean Max Q 1.200605 episode total reward 3  Max episode reward so far 8  Game length 324  Game counts 672
# Iteration 169000	Training step 39750/4000000  Mean Max Q 1.151773 episode total reward 3  Max episode reward so far 8  Game length 254  Game counts 675
# Iteration 170000	Training step 40000/4000000  Mean Max Q 1.048522 episode total reward 5  Max episode reward so far 8  Game length 477  Game counts 678
# Iteration 171000	Training step 40250/4000000  Mean Max Q 1.065879 episode total reward 1  Max episode reward so far 8  Game length 138  Game counts 683
# Iteration 172000	Training step 40500/4000000  Mean Max Q 1.188530 episode total reward 0  Max episode reward so far 8  Game length 132  Game counts 687
# Iteration 173000	Training step 40750/4000000  Mean Max Q 1.158536 episode total reward 2  Max episode reward so far 8  Game length 223  Game counts 691
# Iteration 174000	Training step 41000/4000000  Mean Max Q 1.076660 episode total reward 0  Max episode reward so far 8  Game length 18  Game counts 697
# Iteration 175000	Training step 41250/4000000  Mean Max Q 1.052880 episode total reward 0  Max episode reward so far 8  Game length 91  Game counts 701
# Iteration 176000	Training step 41500/4000000  Mean Max Q 1.156703 episode total reward 0  Max episode reward so far 8  Game length 80  Game counts 704
# Iteration 177000	Training step 41750/4000000  Mean Max Q 1.244688 episode total reward 0  Max episode reward so far 8  Game length 0  Game counts 708
# Iteration 178000	Training step 42000/4000000  Mean Max Q 1.110069 episode total reward 1  Max episode reward so far 8  Game length 107  Game counts 712
# Iteration 179000	Training step 42250/4000000  Mean Max Q 1.056993 episode total reward 0  Max episode reward so far 8  Game length 115  Game counts 716
# Iteration 180000	Training step 42500/4000000  Mean Max Q 1.163694 episode total reward 0  Max episode reward so far 8  Game length 73  Game counts 720
# Iteration 181000	Training step 42750/4000000  Mean Max Q 1.225953 episode total reward 0  Max episode reward so far 8  Game length 48  Game counts 724
# Iteration 182000	Training step 43000/4000000  Mean Max Q 1.125995 episode total reward 0  Max episode reward so far 8  Game length 82  Game counts 728
# Iteration 183000	Training step 43250/4000000  Mean Max Q 1.098955 episode total reward 5  Max episode reward so far 8  Game length 418  Game counts 731
# Iteration 184000	Training step 43500/4000000  Mean Max Q 1.203678 episode total reward 0  Max episode reward so far 8  Game length 55  Game counts 736
# Iteration 185000	Training step 43750/4000000  Mean Max Q 1.222965 episode total reward 0  Max episode reward so far 8  Game length 81  Game counts 740
# Iteration 186000	Training step 44000/4000000  Mean Max Q 1.141958 episode total reward 1  Max episode reward so far 8  Game length 109  Game counts 745
# Iteration 187000	Training step 44250/4000000  Mean Max Q 1.173177 episode total reward 0  Max episode reward so far 8  Game length 115  Game counts 749
# Iteration 188000	Training step 44500/4000000  Mean Max Q 1.096392 episode total reward 0  Max episode reward so far 8  Game length 111  Game counts 754
# Iteration 189000	Training step 44750/4000000  Mean Max Q 1.225362 episode total reward 1  Max episode reward so far 8  Game length 179  Game counts 758
# Iteration 190000	Training step 45000/4000000  Mean Max Q 1.092580 episode total reward 0  Max episode reward so far 8  Game length 15  Game counts 763
# Iteration 191000	Training step 45250/4000000  Mean Max Q 1.126270 episode total reward 0  Max episode reward so far 8  Game length 120  Game counts 767
# Iteration 192000	Training step 45500/4000000  Mean Max Q 1.184654 episode total reward 2  Max episode reward so far 8  Game length 242  Game counts 771
# Iteration 193000	Training step 45750/4000000  Mean Max Q 1.079590 episode total reward 1  Max episode reward so far 8  Game length 138  Game counts 776
# Iteration 194000	Training step 46000/4000000  Mean Max Q 1.083005 episode total reward 0  Max episode reward so far 8  Game length 104  Game counts 780
# Iteration 195000	Training step 46250/4000000  Mean Max Q 1.096529 episode total reward 0  Max episode reward so far 8  Game length 97  Game counts 784
# Iteration 196000	Training step 46500/4000000  Mean Max Q 1.079642 episode total reward 2  Max episode reward so far 8  Game length 262  Game counts 788
# Iteration 197000	Training step 46750/4000000  Mean Max Q 1.205125 episode total reward 0  Max episode reward so far 8  Game length 30  Game counts 793
# Iteration 198000	Training step 47000/4000000  Mean Max Q 1.191836 episode total reward 1  Max episode reward so far 8  Game length 228  Game counts 797
# Iteration 199000	Training step 47250/4000000  Mean Max Q 1.184444 episode total reward 0  Max episode reward so far 8  Game length 19  Game counts 801
# Iteration 200000	Training step 47500/4000000  Mean Max Q 1.197440 episode total reward 0  Max episode reward so far 8  Game length 32  Game counts 805
# Iteration 201000	Training step 47750/4000000  Mean Max Q 1.087703 episode total reward 0  Max episode reward so far 8  Game length 77  Game counts 809
# Iteration 202000	Training step 48000/4000000  Mean Max Q 1.094275 episode total reward 0  Max episode reward so far 8  Game length 111  Game counts 812
# Iteration 203000	Training step 48250/4000000  Mean Max Q 1.204900 episode total reward 0  Max episode reward so far 8  Game length 51  Game counts 816
# Iteration 204000	Training step 48500/4000000  Mean Max Q 1.097836 episode total reward 1  Max episode reward so far 8  Game length 150  Game counts 820
# Iteration 205000	Training step 48750/4000000  Mean Max Q 1.097319 episode total reward 3  Max episode reward so far 8  Game length 331  Game counts 823
# Iteration 206000	Training step 49000/4000000  Mean Max Q 1.202021 episode total reward 2  Max episode reward so far 8  Game length 218  Game counts 827
# Iteration 207000	Training step 49250/4000000  Mean Max Q 1.188701 episode total reward 0  Max episode reward so far 8  Game length 2  Game counts 832
# Iteration 208000	Training step 49500/4000000  Mean Max Q 1.085545 episode total reward 0  Max episode reward so far 8  Game length 59  Game counts 836
# Iteration 209000	Training step 49750/4000000  Mean Max Q 1.105677 episode total reward 0  Max episode reward so far 8  Game length 5  Game counts 840
# Iteration 210000	Training step 50000/4000000  Mean Max Q 1.097394 episode total reward 2  Max episode reward so far 8  Game length 183  Game counts 843
# Iteration 211000	Training step 50250/4000000  Mean Max Q 1.096685 episode total reward 0  Max episode reward so far 8  Game length 2  Game counts 848
# Iteration 212000	Training step 50500/4000000  Mean Max Q 1.164651 episode total reward 1  Max episode reward so far 8  Game length 107  Game counts 852
# Iteration 213000	Training step 50750/4000000  Mean Max Q 1.191086 episode total reward 0  Max episode reward so far 8  Game length 16  Game counts 854
# Iteration 214000	Training step 51000/4000000  Mean Max Q 1.345067 episode total reward 1  Max episode reward so far 8  Game length 163  Game counts 858
# Iteration 215000	Training step 51250/4000000  Mean Max Q 1.103787 episode total reward 2  Max episode reward so far 8  Game length 290  Game counts 862
# Iteration 216000	Training step 51500/4000000  Mean Max Q 1.250202 episode total reward 0  Max episode reward so far 8  Game length 122  Game counts 866
# Iteration 217000	Training step 51750/4000000  Mean Max Q 1.164891 episode total reward 0  Max episode reward so far 8  Game length 8  Game counts 871
# Iteration 218000	Training step 52000/4000000  Mean Max Q 1.108778 episode total reward 0  Max episode reward so far 8  Game length 113  Game counts 875
# Iteration 219000	Training step 52250/4000000  Mean Max Q 1.123113 episode total reward 2  Max episode reward so far 8  Game length 281  Game counts 878
# Iteration 220000	Training step 52500/4000000  Mean Max Q 1.194668 episode total reward 0  Max episode reward so far 8  Game length 46  Game counts 882
# Iteration 221000	Training step 52750/4000000  Mean Max Q 1.141214 episode total reward 0  Max episode reward so far 8  Game length 30  Game counts 887
# Iteration 222000	Training step 53000/4000000  Mean Max Q 1.112503 episode total reward 0  Max episode reward so far 8  Game length 42  Game counts 891
# Iteration 223000	Training step 53250/4000000  Mean Max Q 1.236925 episode total reward 1  Max episode reward so far 8  Game length 79  Game counts 895
# Iteration 224000	Training step 53500/4000000  Mean Max Q 1.339205 episode total reward 0  Max episode reward so far 8  Game length 103  Game counts 898
# Iteration 225000	Training step 53750/4000000  Mean Max Q 1.098463 episode total reward 0  Max episode reward so far 8  Game length 26  Game counts 903
# Iteration 226000	Training step 54000/4000000  Mean Max Q 1.125522 episode total reward 0  Max episode reward so far 8  Game length 53  Game counts 907
# Iteration 227000	Training step 54250/4000000  Mean Max Q 1.258565 episode total reward 1  Max episode reward so far 8  Game length 138  Game counts 911
# Iteration 228000	Training step 54500/4000000  Mean Max Q 1.297946 episode total reward 1  Max episode reward so far 8  Game length 176  Game counts 915
# Iteration 229000	Training step 54750/4000000  Mean Max Q 1.284054 episode total reward 0  Max episode reward so far 8  Game length 164  Game counts 918
# Iteration 230000	Training step 55000/4000000  Mean Max Q 1.098266 episode total reward 0  Max episode reward so far 8  Game length 100  Game counts 923
# Iteration 231000	Training step 55250/4000000  Mean Max Q 1.154528 episode total reward 2  Max episode reward so far 8  Game length 169  Game counts 927
# Iteration 232000	Training step 55500/4000000  Mean Max Q 1.457193 episode total reward 0  Max episode reward so far 8  Game length 20  Game counts 932
# Iteration 233000	Training step 55750/4000000  Mean Max Q 1.146063 episode total reward 1  Max episode reward so far 8  Game length 175  Game counts 935
# Iteration 234000	Training step 56000/4000000  Mean Max Q 1.079293 episode total reward 3  Max episode reward so far 8  Game length 315  Game counts 939
# Iteration 235000	Training step 56250/4000000  Mean Max Q 1.152933 episode total reward 1  Max episode reward so far 8  Game length 162  Game counts 943
# Iteration 236000	Training step 56500/4000000  Mean Max Q 1.225683 episode total reward 0  Max episode reward so far 8  Game length 29  Game counts 947
# Iteration 237000	Training step 56750/4000000  Mean Max Q 1.149047 episode total reward 1  Max episode reward so far 8  Game length 123  Game counts 951
# Iteration 238000	Training step 57000/4000000  Mean Max Q 1.189510 episode total reward 0  Max episode reward so far 8  Game length 23  Game counts 955
# Iteration 239000	Training step 57250/4000000  Mean Max Q 1.097250 episode total reward 0  Max episode reward so far 8  Game length 18  Game counts 960
# Iteration 240000	Training step 57500/4000000  Mean Max Q 1.090341 episode total reward 1  Max episode reward so far 8  Game length 230  Game counts 964
# Iteration 241000	Training step 57750/4000000  Mean Max Q 1.291523 episode total reward 2  Max episode reward so far 8  Game length 279  Game counts 968
# Iteration 242000	Training step 58000/4000000  Mean Max Q 1.117510 episode total reward 0  Max episode reward so far 8  Game length 61  Game counts 973
# Iteration 243000	Training step 58250/4000000  Mean Max Q 1.194261 episode total reward 1  Max episode reward so far 8  Game length 208  Game counts 977
# Iteration 244000	Training step 58500/4000000  Mean Max Q 1.184455 episode total reward 3  Max episode reward so far 8  Game length 288  Game counts 981
# Iteration 245000	Training step 58750/4000000  Mean Max Q 1.249733 episode total reward 2  Max episode reward so far 8  Game length 135  Game counts 985
# Iteration 246000	Training step 59000/4000000  Mean Max Q 1.183090 episode total reward 0  Max episode reward so far 8  Game length 103  Game counts 989
# Iteration 247000	Training step 59250/4000000  Mean Max Q 1.224805 episode total reward 3  Max episode reward so far 8  Game length 268  Game counts 992
# Iteration 248000	Training step 59500/4000000  Mean Max Q 1.239061 episode total reward 0  Max episode reward so far 8  Game length 118  Game counts 996
# Iteration 249000	Training step 59750/4000000  Mean Max Q 1.305133 episode total reward 0  Max episode reward so far 8  Game length 119  Game counts 1000
# Iteration 250000	Training step 60000/4000000  Mean Max Q 1.303663 episode total reward 0  Max episode reward so far 8  Game length 136  Game counts 1004
# Iteration 251000	Training step 60250/4000000  Mean Max Q 1.273364 episode total reward 2  Max episode reward so far 8  Game length 198  Game counts 1008
# Iteration 252000	Training step 60500/4000000  Mean Max Q 1.119516 episode total reward 1  Max episode reward so far 8  Game length 103  Game counts 1012
# Iteration 253000	Training step 60750/4000000  Mean Max Q 1.247474 episode total reward 0  Max episode reward so far 8  Game length 37  Game counts 1016
# Iteration 254000	Training step 61000/4000000  Mean Max Q 1.095760 episode total reward 2  Max episode reward so far 8  Game length 194  Game counts 1020
# Iteration 255000	Training step 61250/4000000  Mean Max Q 1.107404 episode total reward 0  Max episode reward so far 8  Game length 128  Game counts 1025
# Iteration 256000	Training step 61500/4000000  Mean Max Q 1.159094 episode total reward 0  Max episode reward so far 8  Game length 64  Game counts 1029
# Iteration 257000	Training step 61750/4000000  Mean Max Q 1.245970 episode total reward 2  Max episode reward so far 8  Game length 210  Game counts 1033
# Iteration 258000	Training step 62000/4000000  Mean Max Q 1.325452 episode total reward 0  Max episode reward so far 8  Game length 166  Game counts 1037
# Iteration 259000	Training step 62250/4000000  Mean Max Q 1.261607 episode total reward 2  Max episode reward so far 8  Game length 256  Game counts 1040
# Iteration 260000	Training step 62500/4000000  Mean Max Q 1.246475 episode total reward 0  Max episode reward so far 8  Game length 99  Game counts 1044
# Iteration 261000	Training step 62750/4000000  Mean Max Q 1.192129 episode total reward 0  Max episode reward so far 8  Game length 73  Game counts 1048
# Iteration 262000	Training step 63000/4000000  Mean Max Q 1.123051 episode total reward 0  Max episode reward so far 8  Game length 112  Game counts 1051
# Iteration 263000	Training step 63250/4000000  Mean Max Q 1.362567 episode total reward 0  Max episode reward so far 8  Game length 90  Game counts 1054
# Iteration 264000	Training step 63500/4000000  Mean Max Q 1.272973 episode total reward 1  Max episode reward so far 8  Game length 208  Game counts 1058
# Iteration 265000	Training step 63750/4000000  Mean Max Q 1.124039 episode total reward 0  Max episode reward so far 8  Game length 193  Game counts 1063
# Iteration 266000	Training step 64000/4000000  Mean Max Q 1.269372 episode total reward 1  Max episode reward so far 8  Game length 162  Game counts 1067
# Iteration 267000	Training step 64250/4000000  Mean Max Q 1.119146 episode total reward 4  Max episode reward so far 8  Game length 338  Game counts 1070
# Iteration 268000	Training step 64500/4000000  Mean Max Q 1.108745 episode total reward 0  Max episode reward so far 8  Game length 59  Game counts 1075
# Iteration 269000	Training step 64750/4000000  Mean Max Q 1.315338 episode total reward 2  Max episode reward so far 8  Game length 179  Game counts 1078
# Iteration 270000	Training step 65000/4000000  Mean Max Q 1.151865 episode total reward 1  Max episode reward so far 8  Game length 133  Game counts 1082
# Iteration 271000	Training step 65250/4000000  Mean Max Q 1.266117 episode total reward 0  Max episode reward so far 8  Game length 125  Game counts 1086
# Iteration 272000	Training step 65500/4000000  Mean Max Q 1.096699 episode total reward 2  Max episode reward so far 8  Game length 247  Game counts 1090
# Iteration 273000	Training step 65750/4000000  Mean Max Q 1.108925 episode total reward 1  Max episode reward so far 8  Game length 69  Game counts 1095
# Iteration 274000	Training step 66000/4000000  Mean Max Q 1.325942 episode total reward 0  Max episode reward so far 8  Game length 17  Game counts 1099
# Iteration 275000	Training step 66250/4000000  Mean Max Q 1.339572 episode total reward 0  Max episode reward so far 8  Game length 59  Game counts 1102
# Iteration 276000	Training step 66500/4000000  Mean Max Q 1.209840 episode total reward 0  Max episode reward so far 8  Game length 32  Game counts 1106
# Iteration 277000	Training step 66750/4000000  Mean Max Q 1.099235 episode total reward 1  Max episode reward so far 8  Game length 160  Game counts 1110
# Iteration 278000	Training step 67000/4000000  Mean Max Q 1.323460 episode total reward 0  Max episode reward so far 8  Game length 9  Game counts 1114
# Iteration 279000	Training step 67250/4000000  Mean Max Q 1.107656 episode total reward 0  Max episode reward so far 8  Game length 39  Game counts 1119
# Iteration 280000	Training step 67500/4000000  Mean Max Q 1.238295 episode total reward 0  Max episode reward so far 8  Game length 142  Game counts 1121
# Iteration 281000	Training step 67750/4000000  Mean Max Q 1.103319 episode total reward 0  Max episode reward so far 8  Game length 24  Game counts 1126
# Iteration 282000	Training step 68000/4000000  Mean Max Q 1.196368 episode total reward 1  Max episode reward so far 8  Game length 215  Game counts 1130
# Iteration 283000	Training step 68250/4000000  Mean Max Q 1.274236 episode total reward 1  Max episode reward so far 8  Game length 211  Game counts 1134
# Iteration 284000	Training step 68500/4000000  Mean Max Q 1.315919 episode total reward 1  Max episode reward so far 8  Game length 170  Game counts 1138
# Iteration 285000	Training step 68750/4000000  Mean Max Q 1.096527 episode total reward 0  Max episode reward so far 8  Game length 13  Game counts 1143
# Iteration 286000	Training step 69000/4000000  Mean Max Q 1.097924 episode total reward 1  Max episode reward so far 8  Game length 118  Game counts 1147
# Iteration 287000	Training step 69250/4000000  Mean Max Q 1.260884 episode total reward 1  Max episode reward so far 8  Game length 112  Game counts 1151
# Iteration 288000	Training step 69500/4000000  Mean Max Q 1.193535 episode total reward 0  Max episode reward so far 8  Game length 50  Game counts 1155
# Iteration 289000	Training step 69750/4000000  Mean Max Q 1.314406 episode total reward 1  Max episode reward so far 8  Game length 184  Game counts 1158
# Iteration 290000	Training step 70000/4000000  Mean Max Q 1.324337 episode total reward 1  Max episode reward so far 8  Game length 107  Game counts 1163
# Iteration 291000	Training step 70250/4000000  Mean Max Q 1.105785 episode total reward 1  Max episode reward so far 8  Game length 168  Game counts 1167
# Iteration 292000	Training step 70500/4000000  Mean Max Q 1.388933 episode total reward 2  Max episode reward so far 8  Game length 249  Game counts 1169
# Iteration 293000	Training step 70750/4000000  Mean Max Q 1.318383 episode total reward 0  Max episode reward so far 8  Game length 40  Game counts 1173
# Iteration 294000	Training step 71000/4000000  Mean Max Q 1.272425 episode total reward 2  Max episode reward so far 8  Game length 208  Game counts 1177
# Iteration 295000	Training step 71250/4000000  Mean Max Q 1.214661 episode total reward 1  Max episode reward so far 8  Game length 161  Game counts 1181
# Iteration 296000	Training step 71500/4000000  Mean Max Q 1.583678 episode total reward 0  Max episode reward so far 8  Game length 61  Game counts 1184
# Iteration 297000	Training step 71750/4000000  Mean Max Q 1.456119 episode total reward 2  Max episode reward so far 8  Game length 258  Game counts 1186
# Iteration 298000	Training step 72000/4000000  Mean Max Q 1.345849 episode total reward 0  Max episode reward so far 8  Game length 122  Game counts 1190
# Iteration 299000	Training step 72250/4000000  Mean Max Q 1.221586 episode total reward 0  Max episode reward so far 8  Game length 17  Game counts 1194
# Iteration 300000	Training step 72500/4000000  Mean Max Q 1.098377 episode total reward 0  Max episode reward so far 8  Game length 107  Game counts 1198
# Iteration 301000	Training step 72750/4000000  Mean Max Q 1.314313 episode total reward 1  Max episode reward so far 8  Game length 175  Game counts 1202
# Iteration 302000	Training step 73000/4000000  Mean Max Q 1.105681 episode total reward 0  Max episode reward so far 8  Game length 69  Game counts 1207
# Iteration 303000	Training step 73250/4000000  Mean Max Q 1.111230 episode total reward 1  Max episode reward so far 8  Game length 206  Game counts 1210
# Iteration 304000	Training step 73500/4000000  Mean Max Q 1.233903 episode total reward 3  Max episode reward so far 8  Game length 319  Game counts 1213
# Iteration 305000	Training step 73750/4000000  Mean Max Q 1.101590 episode total reward 1  Max episode reward so far 8  Game length 178  Game counts 1217
# Iteration 306000	Training step 74000/4000000  Mean Max Q 1.275888 episode total reward 1  Max episode reward so far 8  Game length 116  Game counts 1221
# Iteration 307000	Training step 74250/4000000  Mean Max Q 1.107269 episode total reward 2  Max episode reward so far 8  Game length 169  Game counts 1225
# Iteration 308000	Training step 74500/4000000  Mean Max Q 1.187379 episode total reward 0  Max episode reward so far 8  Game length 31  Game counts 1229
# Iteration 309000	Training step 74750/4000000  Mean Max Q 1.112099 episode total reward 0  Max episode reward so far 8  Game length 42  Game counts 1234
# Iteration 310000	Training step 75000/4000000  Mean Max Q 1.363448 episode total reward 0  Max episode reward so far 8  Game length 124  Game counts 1237
# Iteration 311000	Training step 75250/4000000  Mean Max Q 1.355286 episode total reward 0  Max episode reward so far 8  Game length 52  Game counts 1241
# Iteration 312000	Training step 75500/4000000  Mean Max Q 1.343061 episode total reward 0  Max episode reward so far 8  Game length 35  Game counts 1245
# Iteration 313000	Training step 75750/4000000  Mean Max Q 1.377105 episode total reward 1  Max episode reward so far 8  Game length 158  Game counts 1248
# Iteration 314000	Training step 76000/4000000  Mean Max Q 1.268677 episode total reward 0  Max episode reward so far 8  Game length 47  Game counts 1253
# Iteration 315000	Training step 76250/4000000  Mean Max Q 1.240418 episode total reward 2  Max episode reward so far 8  Game length 151  Game counts 1257
# Iteration 316000	Training step 76500/4000000  Mean Max Q 1.418516 episode total reward 0  Max episode reward so far 8  Game length 113  Game counts 1261
# Iteration 317000	Training step 76750/4000000  Mean Max Q 1.265443 episode total reward 0  Max episode reward so far 8  Game length 162  Game counts 1265
# Iteration 318000	Training step 77000/4000000  Mean Max Q 1.459519 episode total reward 0  Max episode reward so far 8  Game length 129  Game counts 1269
# Iteration 319000	Training step 77250/4000000  Mean Max Q 1.474926 episode total reward 3  Max episode reward so far 8  Game length 315  Game counts 1272
# Iteration 320000	Training step 77500/4000000  Mean Max Q 1.464425 episode total reward 2  Max episode reward so far 8  Game length 124  Game counts 1276
# Iteration 321000	Training step 77750/4000000  Mean Max Q 1.138455 episode total reward 0  Max episode reward so far 8  Game length 77  Game counts 1281
# Iteration 322000	Training step 78000/4000000  Mean Max Q 1.497106 episode total reward 2  Max episode reward so far 8  Game length 190  Game counts 1284
# Iteration 323000	Training step 78250/4000000  Mean Max Q 1.521835 episode total reward 0  Max episode reward so far 8  Game length 20  Game counts 1288
# Iteration 324000	Training step 78500/4000000  Mean Max Q 1.268503 episode total reward 1  Max episode reward so far 8  Game length 200  Game counts 1291
# Iteration 325000	Training step 78750/4000000  Mean Max Q 1.396514 episode total reward 2  Max episode reward so far 8  Game length 274  Game counts 1295
# Iteration 326000	Training step 79000/4000000  Mean Max Q 1.141161 episode total reward 2  Max episode reward so far 8  Game length 132  Game counts 1299
# ...
# Iteration 1610000	Training step 400000/4000000  Mean Max Q 3.271415 episode total reward 0  Max episode reward so far 15  Game length 54  Game counts 6485
# Iteration 1611000	Training step 400250/4000000  Mean Max Q 3.055790 episode total reward 3  Max episode reward so far 15  Game length 326  Game counts 6488
# Iteration 1612000	Training step 400500/4000000  Mean Max Q 2.645986 episode total reward 1  Max episode reward so far 15  Game length 260  Game counts 6492
# Iteration 1613000	Training step 400750/4000000  Mean Max Q 3.102044 episode total reward 1  Max episode reward so far 15  Game length 81  Game counts 6497
# Iteration 1614000	Training step 401000/4000000  Mean Max Q 2.937744 episode total reward 0  Max episode reward so far 15  Game length 84  Game counts 6501
# Iteration 1615000	Training step 401250/4000000  Mean Max Q 3.547618 episode total reward 0  Max episode reward so far 15  Game length 35  Game counts 6505
# Iteration 1616000	Training step 401500/4000000  Mean Max Q 4.345369 episode total reward 0  Max episode reward so far 15  Game length 48  Game counts 6508
# Iteration 1617000	Training step 401750/4000000  Mean Max Q 3.400105 episode total reward 0  Max episode reward so far 15  Game length 0  Game counts 6512
# Iteration 1618000	Training step 402000/4000000  Mean Max Q 3.447701 episode total reward 2  Max episode reward so far 15  Game length 244  Game counts 6515
# Iteration 1619000	Training step 402250/4000000  Mean Max Q 3.170679 episode total reward 1  Max episode reward so far 15  Game length 97  Game counts 6520
# Iteration 1620000	Training step 402500/4000000  Mean Max Q 3.320992 episode total reward 0  Max episode reward so far 15  Game length 78  Game counts 6524
# Iteration 1621000	Training step 402750/4000000  Mean Max Q 4.311868 episode total reward 2  Max episode reward so far 15  Game length 263  Game counts 6527
# Iteration 1622000	Training step 403000/4000000  Mean Max Q 3.082766 episode total reward 0  Max episode reward so far 15  Game length 149  Game counts 6531
# Iteration 1623000	Training step 403250/4000000  Mean Max Q 2.943987 episode total reward 1  Max episode reward so far 15  Game length 130  Game counts 6536
# Iteration 1624000	Training step 403500/4000000  Mean Max Q 3.410967 episode total reward 0  Max episode reward so far 15  Game length 52  Game counts 6540
# Iteration 1625000	Training step 403750/4000000  Mean Max Q 2.649292 episode total reward 1  Max episode reward so far 15  Game length 140  Game counts 6545
# Iteration 1626000	Training step 404000/4000000  Mean Max Q 3.045164 episode total reward 0  Max episode reward so far 15  Game length 5  Game counts 6549
# Iteration 1627000	Training step 404250/4000000  Mean Max Q 3.267212 episode total reward 0  Max episode reward so far 15  Game length 77  Game counts 6553
# Iteration 1628000	Training step 404500/4000000  Mean Max Q 3.292515 episode total reward 0  Max episode reward so far 15  Game length 145  Game counts 6557
# Iteration 1629000	Training step 404750/4000000  Mean Max Q 3.091581 episode total reward 0  Max episode reward so far 15  Game length 54  Game counts 6562
# Iteration 1630000	Training step 405000/4000000  Mean Max Q 3.099830 episode total reward 2  Max episode reward so far 15  Game length 218  Game counts 6566
# Iteration 1631000	Training step 405250/4000000  Mean Max Q 3.049461 episode total reward 1  Max episode reward so far 15  Game length 203  Game counts 6570
# Iteration 1632000	Training step 405500/4000000  Mean Max Q 2.612325 episode total reward 0  Max episode reward so far 15  Game length 151  Game counts 6575
# Iteration 1633000	Training step 405750/4000000  Mean Max Q 3.080970 episode total reward 1  Max episode reward so far 15  Game length 190  Game counts 6579
# Iteration 1634000	Training step 406000/4000000  Mean Max Q 3.078967 episode total reward 0  Max episode reward so far 15  Game length 115  Game counts 6583
# Iteration 1635000	Training step 406250/4000000  Mean Max Q 2.622258 episode total reward 0  Max episode reward so far 15  Game length 178  Game counts 6587
# Iteration 1636000	Training step 406500/4000000  Mean Max Q 3.012050 episode total reward 1  Max episode reward so far 15  Game length 172  Game counts 6591
# Iteration 1637000	Training step 406750/4000000  Mean Max Q 3.107734 episode total reward 0  Max episode reward so far 15  Game length 152  Game counts 6595
# Iteration 1638000	Training step 407000/4000000  Mean Max Q 3.290333 episode total reward 3  Max episode reward so far 15  Game length 292  Game counts 6598
# Iteration 1639000	Training step 407250/4000000  Mean Max Q 2.607800 episode total reward 0  Max episode reward so far 15  Game length 114  Game counts 6603
# Iteration 1640000	Training step 407500/4000000  Mean Max Q 3.149116 episode total reward 0  Max episode reward so far 15  Game length 87  Game counts 6608
# Iteration 1641000	Training step 407750/4000000  Mean Max Q 3.074527 episode total reward 0  Max episode reward so far 15  Game length 50  Game counts 6612
# Iteration 1642000	Training step 408000/4000000  Mean Max Q 2.917551 episode total reward 2  Max episode reward so far 15  Game length 138  Game counts 6617
# Iteration 1643000	Training step 408250/4000000  Mean Max Q 3.033978 episode total reward 1  Max episode reward so far 15  Game length 134  Game counts 6621
# Iteration 1644000	Training step 408500/4000000  Mean Max Q 3.418724 episode total reward 0  Max episode reward so far 15  Game length 85  Game counts 6625
# Iteration 1645000	Training step 408750/4000000  Mean Max Q 2.628637 episode total reward 1  Max episode reward so far 15  Game length 87  Game counts 6629
# Iteration 1646000	Training step 409000/4000000  Mean Max Q 3.386043 episode total reward 0  Max episode reward so far 15  Game length 101  Game counts 6632
# Iteration 1647000	Training step 409250/4000000  Mean Max Q 3.095905 episode total reward 0  Max episode reward so far 15  Game length 47  Game counts 6637
# Iteration 1648000	Training step 409500/4000000  Mean Max Q 2.842671 episode total reward 0  Max episode reward so far 15  Game length 65  Game counts 6641
# Iteration 1649000	Training step 409750/4000000  Mean Max Q 3.120351 episode total reward 2  Max episode reward so far 15  Game length 221  Game counts 6645
# Iteration 1650000	Training step 410000/4000000  Mean Max Q 3.225740 episode total reward 0  Max episode reward so far 15  Game length 4  Game counts 6649
# Iteration 1651000	Training step 410250/4000000  Mean Max Q 3.106105 episode total reward 1  Max episode reward so far 15  Game length 106  Game counts 6653
# Iteration 1652000	Training step 410500/4000000  Mean Max Q 2.590352 episode total reward 0  Max episode reward so far 15  Game length 36  Game counts 6658
# Iteration 1653000	Training step 410750/4000000  Mean Max Q 3.078291 episode total reward 0  Max episode reward so far 15  Game length 22  Game counts 6662
# Iteration 1654000	Training step 411000/4000000  Mean Max Q 3.066135 episode total reward 0  Max episode reward so far 15  Game length 5  Game counts 6666
# Iteration 1655000	Training step 411250/4000000  Mean Max Q 2.979412 episode total reward 0  Max episode reward so far 15  Game length 38  Game counts 6670
# Iteration 1656000	Training step 411500/4000000  Mean Max Q 2.521710 episode total reward 0  Max episode reward so far 15  Game length 56  Game counts 6672
# Iteration 1657000	Training step 411750/4000000  Mean Max Q 3.088717 episode total reward 0  Max episode reward so far 15  Game length 51  Game counts 6676
# Iteration 1658000	Training step 412000/4000000  Mean Max Q 3.666862 episode total reward 0  Max episode reward so far 15  Game length 61  Game counts 6680
# Iteration 1659000	Training step 412250/4000000  Mean Max Q 3.111554 episode total reward 0  Max episode reward so far 15  Game length 107  Game counts 6684
# Iteration 1660000	Training step 412500/4000000  Mean Max Q 2.844785 episode total reward 0  Max episode reward so far 15  Game length 24  Game counts 6689
# Iteration 1661000	Training step 412750/4000000  Mean Max Q 2.823646 episode total reward 0  Max episode reward so far 15  Game length 109  Game counts 6692
# Iteration 1662000	Training step 413000/4000000  Mean Max Q 2.767480 episode total reward 1  Max episode reward so far 15  Game length 224  Game counts 6695
# Iteration 1663000	Training step 413250/4000000  Mean Max Q 3.453201 episode total reward 0  Max episode reward so far 15  Game length 149  Game counts 6699
# Iteration 1664000	Training step 413500/4000000  Mean Max Q 2.529263 episode total reward 1  Max episode reward so far 15  Game length 175  Game counts 6704
# Iteration 1665000	Training step 413750/4000000  Mean Max Q 2.762659 episode total reward 0  Max episode reward so far 15  Game length 131  Game counts 6709
# Iteration 1666000	Training step 414000/4000000  Mean Max Q 3.022039 episode total reward 2  Max episode reward so far 15  Game length 225  Game counts 6713
# Iteration 1667000	Training step 414250/4000000  Mean Max Q 2.581293 episode total reward 0  Max episode reward so far 15  Game length 166  Game counts 6717
# Iteration 1668000	Training step 414500/4000000  Mean Max Q 3.146338 episode total reward 0  Max episode reward so far 15  Game length 36  Game counts 6721
# Iteration 1669000	Training step 414750/4000000  Mean Max Q 4.075693 episode total reward 0  Max episode reward so far 15  Game length 27  Game counts 6724
# Iteration 1670000	Training step 415000/4000000  Mean Max Q 2.783482 episode total reward 1  Max episode reward so far 15  Game length 120  Game counts 6727
# Iteration 1671000	Training step 415250/4000000  Mean Max Q 2.663747 episode total reward 2  Max episode reward so far 15  Game length 202  Game counts 6731
# Iteration 1672000	Training step 415500/4000000  Mean Max Q 3.388562 episode total reward 0  Max episode reward so far 15  Game length 69  Game counts 6736
# Iteration 1673000	Training step 415750/4000000  Mean Max Q 3.153877 episode total reward 1  Max episode reward so far 15  Game length 83  Game counts 6740
# Iteration 1674000	Training step 416000/4000000  Mean Max Q 2.566598 episode total reward 2  Max episode reward so far 15  Game length 299  Game counts 6744
# Iteration 1675000	Training step 416250/4000000  Mean Max Q 2.593748 episode total reward 1  Max episode reward so far 15  Game length 73  Game counts 6748
# Iteration 1676000	Training step 416500/4000000  Mean Max Q 2.936879 episode total reward 0  Max episode reward so far 15  Game length 108  Game counts 6752
# Iteration 1677000	Training step 416750/4000000  Mean Max Q 2.607240 episode total reward 0  Max episode reward so far 15  Game length 119  Game counts 6756
# Iteration 1678000	Training step 417000/4000000  Mean Max Q 2.601922 episode total reward 1  Max episode reward so far 15  Game length 206  Game counts 6760
# Iteration 1679000	Training step 417250/4000000  Mean Max Q 2.643052 episode total reward 0  Max episode reward so far 15  Game length 20  Game counts 6764
# Iteration 1680000	Training step 417500/4000000  Mean Max Q 2.561273 episode total reward 0  Max episode reward so far 15  Game length 124  Game counts 6768
# Iteration 1681000	Training step 417750/4000000  Mean Max Q 2.962124 episode total reward 2  Max episode reward so far 15  Game length 151  Game counts 6773
# Iteration 1682000	Training step 418000/4000000  Mean Max Q 3.919170 episode total reward 1  Max episode reward so far 15  Game length 181  Game counts 6776
# Iteration 1683000	Training step 418250/4000000  Mean Max Q 3.083290 episode total reward 0  Max episode reward so far 15  Game length 1  Game counts 6781
# Iteration 1684000	Training step 418500/4000000  Mean Max Q 2.535644 episode total reward 0  Max episode reward so far 15  Game length 85  Game counts 6786
# Iteration 1685000	Training step 418750/4000000  Mean Max Q 3.122734 episode total reward 1  Max episode reward so far 15  Game length 177  Game counts 6790
# Iteration 1686000	Training step 419000/4000000  Mean Max Q 2.562955 episode total reward 0  Max episode reward so far 15  Game length 104  Game counts 6795
# Iteration 1687000	Training step 419250/4000000  Mean Max Q 3.956550 episode total reward 2  Max episode reward so far 15  Game length 193  Game counts 6798
# Iteration 1688000	Training step 419500/4000000  Mean Max Q 2.560237 episode total reward 0  Max episode reward so far 15  Game length 67  Game counts 6803
# Iteration 1689000	Training step 419750/4000000  Mean Max Q 2.971403 episode total reward 3  Max episode reward so far 15  Game length 251  Game counts 6807
# Iteration 1690000	Training step 420000/4000000  Mean Max Q 2.984417 episode total reward 0  Max episode reward so far 15  Game length 52  Game counts 6811
# Iteration 1691000	Training step 420250/4000000  Mean Max Q 3.251178 episode total reward 3  Max episode reward so far 15  Game length 256  Game counts 6815
# Iteration 1692000	Training step 420500/4000000  Mean Max Q 2.612984 episode total reward 2  Max episode reward so far 15  Game length 144  Game counts 6820
# Iteration 1693000	Training step 420750/4000000  Mean Max Q 2.928595 episode total reward 0  Max episode reward so far 15  Game length 60  Game counts 6824
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-c07e2a0ddb70> in <module>()
#      79
#      80     # train online q network
# ---> 81     _, loss_val = sess.run([training_op,loss], feed_dict={online_q.inputs:X_state_val, input_action: X_action_val, y:y_val})
#      82
#      83     # copy online q network to target network
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
batch_size
# Out:
# 50

# %%
# !pwd
# Out:
# /content
